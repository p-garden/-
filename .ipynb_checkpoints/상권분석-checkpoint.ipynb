# %% [markdown]
# # 지도 시각화 테스트

# %%
pip install geopandas matplotlib
# Out:
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: matplotlib in c:\users\j2982\anaconda 3\lib\site-packages (3.7.2)
# Requirement already satisfied: numpy>=1.22 in c:\users\j2982\anaconda 3\lib\site-packages (from geopandas) (1.24.3)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.9.0-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging in c:\users\j2982\anaconda 3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\j2982\anaconda 3\lib\site-packages (from geopandas) (2.0.3)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.5-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\j2982\anaconda 3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\j2982\anaconda 3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\j2982\anaconda 3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.6.2)
# Requirement already satisfied: six>=1.5 in c:\users\j2982\anaconda 3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    --------------------------------------  317.4/323.6 kB 20.5 MB/s eta 0:00:01
#    ---------------------------------------- 323.6/323.6 kB 6.7 MB/s eta 0:00:00
# Downloading pyogrio-0.9.0-cp311-cp311-win_amd64.whl (15.9 MB)
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#    - -------------------------------------- 0.4/15.9 MB 13.5 MB/s eta 0:00:02
#    -- ------------------------------------- 1.0/15.9 MB 12.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.4/15.9 MB 11.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.9/15.9 MB 11.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.5/15.9 MB 11.4 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/15.9 MB 11.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.5/15.9 MB 11.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.1/15.9 MB 11.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/15.9 MB 11.5 MB/s eta 0:00:01
#    ------------- -------------------------- 5.2/15.9 MB 11.5 MB/s eta 0:00:01
#    -------------- ------------------------- 5.7/15.9 MB 11.5 MB/s eta 0:00:01
#    --------------- ------------------------ 6.3/15.9 MB 11.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.8/15.9 MB 11.4 MB/s eta 0:00:01
#    ------------------ --------------------- 7.3/15.9 MB 11.4 MB/s eta 0:00:01
#    ------------------- -------------------- 7.9/15.9 MB 11.7 MB/s eta 0:00:01
#    -------------------- ------------------- 8.2/15.9 MB 11.4 MB/s eta 0:00:01
#    --------------------- ------------------ 8.6/15.9 MB 11.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.3/15.9 MB 11.2 MB/s eta 0:00:01
#    ------------------------ --------------- 9.8/15.9 MB 11.2 MB/s eta 0:00:01
#    ------------------------- -------------- 10.1/15.9 MB 11.0 MB/s eta 0:00:01
#    -------------------------- ------------- 10.6/15.9 MB 10.9 MB/s eta 0:00:01
#    --------------------------- ------------ 10.9/15.9 MB 10.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.6/15.9 MB 10.9 MB/s eta 0:00:01
#    ------------------------------ --------- 12.2/15.9 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 12.7/15.9 MB 10.9 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.7/15.9 MB 10.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.3/15.9 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 14.8/15.9 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.3/15.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  15.9/15.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 15.9/15.9 MB 9.6 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    - -------------------------------------- 0.2/6.1 MB 5.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/6.1 MB 4.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.6/6.1 MB 4.9 MB/s eta 0:00:02
#    ------ --------------------------------- 1.0/6.1 MB 6.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.5/6.1 MB 7.0 MB/s eta 0:00:01
#    -------------- ------------------------- 2.2/6.1 MB 8.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.7/6.1 MB 8.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.1 MB 9.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.6/6.1 MB 9.3 MB/s eta 0:00:01
#    -------------------------- ------------- 4.1/6.1 MB 9.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.5/6.1 MB 9.6 MB/s eta 0:00:01
#    --------------------------------- ------ 5.1/6.1 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 5.5/6.1 MB 9.5 MB/s eta 0:00:01
#    -------------------------------------- - 5.9/6.1 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 8.6 MB/s eta 0:00:00
# Downloading shapely-2.0.5-cp311-cp311-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------------- -------------------- 0.7/1.4 MB 21.8 MB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.4 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 11.5 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.9.0 pyproj-3.6.1 shapely-2.0.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
plt.rcdefaults()

# %%
file_path = r'C:\Users\j2982\jupyter notebook\안심구역_죽은상권살리기\서울시 상권분석서비스(영역-상권)\서울시 상권분석서비스(영역-상권).shp'
data = gpd.read_file(file_path)
data.head()
# Out:
#   TRDAR_SE_C TRDAR_SE_1 TRDAR_CD         TRDAR_CD_N  XCNTS_VALU  YDNTS_VALU  \
# 0          A       골목상권  3110008    배화여자대학교(박노수미술관)    197093.0    453418.0
# 1          U       관광특구  3001494         종로·청계 관광특구    199796.0    452274.0
# 2          R       전통시장  3130021             신설종합시장    201854.0    452569.0
# 3          R       전통시장  3130002  세종마을음식문화거리(금천교시장)    197423.0    453030.0
# 4          R       전통시장  3130001               통인시장    197351.0    453449.0
#
#   SIGNGU_CD SIGNGU_CD_ ADSTRD_CD   ADSTRD_CD_   RELM_AR  \
# 0     11110        종로구  11110515        청운효자동  149264.0
# 1     11110        종로구  11110615  종로1·2·3·4가동  653127.0
# 2     11110        종로구  11110710         숭인2동    9800.0
# 3     11110        종로구  11110530          사직동   49557.0
# 4     11110        종로구  11110515        청운효자동   38280.0
#
#                                             geometry
# 0  POLYGON ((196955.842 453722.114, 196958.669 45...
# 1  POLYGON ((201385.38 452513.725, 201385.284 452...
# 2  POLYGON ((201937.121 452552.083, 201872.576 45...
# 3  POLYGON ((197550.67 453079.887, 197554.026 453...
# 4  POLYGON ((197428.009 453548.216, 197436.697 45...

# %%
data.plot()
plt.show()

# %% [markdown]
# # 1. 죽은 상권 / 뜨는 상권 정의하기

# %% [markdown]
# ## 파일 불러오기

# %%
import geopandas as gpd

file_path = 'data\서울시 상권분석서비스(영역-상권)\서울시 상권분석서비스(영역-상권).shp'
data = gpd.read_file(file_path)

# %%
import pandas as pd

# 파일 경로를 지정하세요
path_2019_store = 'data/서울시_상권분석서비스(점포-상권)_2019년.csv'
path_2024_store = 'data/서울시 상권분석서비스(점포-상권).csv'
path_2019_sales = 'data/서울시_상권분석서비스(추정매출-상권)_2019년.csv'
path_2024_sales = 'data/서울시 상권분석서비스(추정매출-상권).csv'
path_floating = 'data/서울시 상권분석서비스(길단위인구-상권).csv'

# CSV 파일을 데이터프레임으로 불러오기
df_2019_store = pd.read_csv(path_2019_store, encoding='euc-kr')
df_2024_store = pd.read_csv(path_2024_store, encoding='euc-kr')
df_2019_sales = pd.read_csv(path_2019_sales, encoding='euc-kr')
df_2024_sales = pd.read_csv(path_2024_sales, encoding='euc-kr')
df_floating = pd.read_csv(path_floating, encoding= 'euc-kr')

# 데이터프레임 확인
print(df_2019_store.head())
print(df_2024_store.head())
print(df_2019_sales.head())
print(df_2024_sales.head())
print(df_floating.head())
# Out:
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드               상권_코드_명 서비스_업종_코드  \
# 0      20191        R       전통시장  3130018  동대문문구완구거리(동대문문구완구시장)  CS300043
# 1      20191        D       발달상권  3120165        서래마을카페거리(서래마을)  CS100007
# 2      20191        D       발달상권  3120177               신논현역 1번  CS300015
# 3      20191        A       골목상권  3110508                 서연중학교  CS200041
# 4      20191        A       골목상권  3110241                먹골역 5번  CS300036
#
#   서비스_업종_코드_명  점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0      전자상거래업    10          10    10        1     0        0           0
# 1       치킨전문점     0           1     0        0   100        1           1
# 2          가방     3           3     0        0     0        0           0
# 3         사진관     6           6    17        1     0        0           0
# 4        조명용품     2           2     0        0     0        0           0
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드   상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  \
# 0      20231        U       관광특구  3001491  이태원 관광특구  CS100001       한식음식점
# 1      20231        U       관광특구  3001491  이태원 관광특구  CS100002       중식음식점
# 2      20231        U       관광특구  3001491  이태원 관광특구  CS100003       일식음식점
# 3      20231        U       관광특구  3001491  이태원 관광특구  CS100004       양식음식점
# 4      20231        U       관광특구  3001491  이태원 관광특구  CS100005         제과점
#
#    점포_수  유사_업종_점포_수  개업_율  개업_점포_수  폐업_률  폐업_점포_수  프랜차이즈_점포_수
# 0   165         171     4        6     4        7           6
# 1    18          18     6        1     6        1           0
# 2    22          23     0        0     0        0           1
# 3   236         239     2        4     2        4           3
# 4    21          26     4        1     0        0           5
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명 서비스_업종_코드  \
# 0      20191        D       발달상권  3120037              동대문역사문화공원역  CS200029
# 1      20191        U       관광특구  3001492  명동 남대문 북창동 다동 무교동 관광특구  CS200029
# 2      20191        A       골목상권  3110085                  경리단길남측  CS200029
# 3      20191        A       골목상권  3110166                구의1동주민센터  CS200029
# 4      20191        A       골목상권  3110161                  중곡역 3번  CS200029
#
#   서비스_업종_코드_명  당월_매출_금액  당월_매출_건수  주중_매출_금액  ...  시간대_건수~21_매출_건수  \
# 0         네일숍  20393290       208  17051978  ...               86
# 1         네일숍  73147711      2136  57025458  ...             1270
# 2         네일숍   3000000        40   2337081  ...               14
# 3         네일숍   8443798       153   4984275  ...               64
# 4         네일숍  20756990       305  16694436  ...              196
#
#    시간대_건수~24_매출_건수  남성_매출_건수  여성_매출_건수  연령대_10_매출_건수  연령대_20_매출_건수  \
# 0               27         0       208             0            56
# 1               35        59      2077             0           715
# 2                9         0        40             0             8
# 3               13        13       140             0            52
# 4               36         4       301             0            79
#
#    연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수
# 0            21             0           123                8
# 1           995           236           157               33
# 2            28             5             0                0
# 3            88            13             0                0
# 4            28            68            91               39
#
# [5 rows x 55 columns]
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  \
# 0      20231        A       골목상권  3110001   이북5도청사  CS100001       한식음식점
# 1      20231        A       골목상권  3110001   이북5도청사  CS100008       분식전문점
# 2      20231        A       골목상권  3110001   이북5도청사  CS100009     호프-간이주점
# 3      20231        A       골목상권  3110001   이북5도청사  CS200001      일반교습학원
# 4      20231        A       골목상권  3110002  독립문역 1번  CS100001       한식음식점
#
#     당월_매출_금액  당월_매출_건수   주중_매출_금액  ...  시간대_건수~21_매출_건수  시간대_건수~24_매출_건수  \
# 0  405545335      9975  231456447  ...             3090              211
# 1  117335358     10989   69547384  ...              923                0
# 2   19577767       370   13115990  ...              199              157
# 3   47135947       136   47135947  ...               72                0
# 4  452192952     18282  364090632  ...             4190              491
#
#    남성_매출_건수  여성_매출_건수  연령대_10_매출_건수  연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  \
# 0      5754      3067            38           290           922          1463
# 1      5672      4534            74           632          1369          2286
# 2       219       109             0            18            23            59
# 3        96        40             0             0             8           120
# 4      9732      7751             0          1027          2220          3501
#
#    연령대_50_매출_건수  연령대_60_이상_매출_건수
# 0          2578             3531
# 1          3454             2390
# 2           124              105
# 3             8                0
# 4          4256             6477
#
# [5 rows x 55 columns]
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  총_유동인구_수  \
# 0      20241        U       관광특구  3001496             강남 마이스 관광특구    109292
# 1      20241        U       관광특구  3001495                 잠실 관광특구   4110178
# 2      20241        U       관광특구  3001494              종로?청계 관광특구   8440796
# 3      20241        U       관광특구  3001493            동대문패션타운 관광특구   3384560
# 4      20241        U       관광특구  3001492  명동 남대문 북창동 다동 무교동 관광특구   6889856
#
#    남성_유동인구_수  여성_유동인구_수  연령대_10_유동인구_수  연령대_20_유동인구_수  ...  시간대_14_17_유동인구_수  \
# 0      54238      55054           7982          21853  ...             27041
# 1    1976808    2133370         434196         915211  ...            653233
# 2    4496772    3944023         358062        1523184  ...           1808704
# 3    1595828    1788732         188119         645950  ...            524693
# 4    3343470    3546388         335824        1194547  ...           1706632
#
#    시간대_17_21_유동인구_수  시간대_21_24_유동인구_수  월요일_유동인구_수  화요일_유동인구_수  수요일_유동인구_수  \
# 0             22995              6011       15002       16018       17973
# 1            879474            477929      570999      570194      589977
# 2           1691285            660774     1258576     1328555     1410371
# 3            620807            401942      504854      524755      553766
# 4           1327800            343472     1040403     1133875     1202348
#
#    목요일_유동인구_수  금요일_유동인구_수  토요일_유동인구_수  일요일_유동인구_수
# 0       17774       17305       13328       11892
# 1      580551      598178      621983      578294
# 2     1345939     1334099      998247      765010
# 3      540100      497858      381895      381333
# 4     1130314     1103850      706014      573054
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 원하는 형태의 데이터 테이블 만들기

# %% [markdown]
# 원하는 열만 선택하기

# %% [markdown]
# 서비스 업종별로 나누어져있어 상권별로 접포수, 매출액 합치기

# %%
selected_columns = [
    '기준_년분기_코드', '상권_코드',
    '상권_코드_명', '점포_수',
]
df_2019_store_selected = df_2019_store[selected_columns]
df_2024_store_selected = df_2024_store[selected_columns]
print(df_2019_store_selected.head())
print(df_2024_store_selected.head())
# Out:
#    기준_년분기_코드    상권_코드               상권_코드_명  점포_수
# 0      20191  3130018  동대문문구완구거리(동대문문구완구시장)    10
# 1      20191  3120165        서래마을카페거리(서래마을)     0
# 2      20191  3120177               신논현역 1번     3
# 3      20191  3110508                 서연중학교     6
# 4      20191  3110241                먹골역 5번     2
#    기준_년분기_코드    상권_코드   상권_코드_명  점포_수
# 0      20231  3001491  이태원 관광특구   165
# 1      20231  3001491  이태원 관광특구    18
# 2      20231  3001491  이태원 관광특구    22
# 3      20231  3001491  이태원 관광특구   236
# 4      20231  3001491  이태원 관광특구    21

# %%
df_2019_store_grouped = df_2019_store_selected[df_2019_store_selected['기준_년분기_코드'] == 20191]
df_2019_store_grouped = df_2019_store_grouped.groupby(['기준_년분기_코드', '상권_코드', '상권_코드_명']).agg({
    '점포_수': 'sum',
}).reset_index()
df_2019_store_grouped
# Out:
#       기준_년분기_코드    상권_코드                       상권_코드_명   점포_수
# 0         20191  3001491                      이태원 관광특구   1676
# 1         20191  3001492        명동 남대문 북창동 다동 무교동 관광특구   9063
# 2         20191  3001493                  동대문패션타운 관광특구  13496
# 3         20191  3001494                    종로·청계 관광특구   5158
# 4         20191  3001495                       잠실 관광특구   2212
# ...         ...      ...                           ...    ...
# 1643      20191  3130323                       둔촌역전통시장    167
# 1644      20191  3130324                       길동복조리시장    101
# 1645      20191  3130325                        명일전통시장     88
# 1646      20191  3130326                     고덕 골목형상점가     71
# 1647      20191  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)   2670
#
# [1648 rows x 4 columns]

# %%
df_2024_store_grouped = df_2024_store_selected[df_2024_store_selected['기준_년분기_코드'] == 20241]
df_2024_store_grouped = df_2024_store_grouped.groupby(['기준_년분기_코드', '상권_코드', '상권_코드_명']).agg({
    '점포_수': 'sum',
}).reset_index()
df_2024_store_grouped
# Out:
#       기준_년분기_코드    상권_코드                       상권_코드_명   점포_수
# 0         20241  3001491                      이태원 관광특구   1696
# 1         20241  3001492        명동 남대문 북창동 다동 무교동 관광특구   8269
# 2         20241  3001493                  동대문패션타운 관광특구  11314
# 3         20241  3001494                    종로?청계 관광특구   4878
# 4         20241  3001495                       잠실 관광특구   2376
# ...         ...      ...                           ...    ...
# 1643      20241  3130323                       둔촌역전통시장    166
# 1644      20241  3130324                       길동복조리시장    117
# 1645      20241  3130325                        명일전통시장     99
# 1646      20241  3130326                     고덕 골목형상점가    155
# 1647      20241  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)   2268
#
# [1648 rows x 4 columns]

# %%
#df_2024_store_grouped[df_2024_store_grouped['폐업_점포_수'].isna()]

# %%
df_2019_sales = df_2019_sales[df_2019_sales['기준_년분기_코드'] == 20191]
df_2019_sales_grouped = df_2019_sales.groupby(['기준_년분기_코드', '상권_코드', '상권_코드_명']).agg({
    '당월_매출_금액': 'sum',
}).reset_index()
df_2019_sales_grouped
# Out:
#       기준_년분기_코드    상권_코드                       상권_코드_명      당월_매출_금액
# 0         20191  3001491                      이태원 관광특구   83131949802
# 1         20191  3001492        명동 남대문 북창동 다동 무교동 관광특구  311534240028
# 2         20191  3001493                  동대문패션타운 관광특구  108434508028
# 3         20191  3001494                    종로·청계 관광특구  247895672197
# 4         20191  3001495                       잠실 관광특구  138146453561
# ...         ...      ...                           ...           ...
# 1538      20191  3130323                       둔촌역전통시장    8533725006
# 1539      20191  3130324                       길동복조리시장    3449342814
# 1540      20191  3130325                        명일전통시장    2957301531
# 1541      20191  3130326                     고덕 골목형상점가    3238745432
# 1542      20191  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)   24859243577
#
# [1543 rows x 4 columns]

# %%
df_2024_sales = df_2024_sales[df_2024_sales['기준_년분기_코드'] == 20241]
df_2024_sales_grouped = df_2024_sales.groupby(['기준_년분기_코드', '상권_코드', '상권_코드_명']).agg({
    '당월_매출_금액': 'sum',
}).reset_index()
df_2024_sales_grouped
# Out:
#       기준_년분기_코드    상권_코드                       상권_코드_명      당월_매출_금액
# 0         20241  3001491                      이태원 관광특구   86806837461
# 1         20241  3001492        명동 남대문 북창동 다동 무교동 관광특구  409476541286
# 2         20241  3001493                  동대문패션타운 관광특구  120372966569
# 3         20241  3001494                    종로?청계 관광특구  246968942914
# 4         20241  3001495                       잠실 관광특구  366115962860
# ...         ...      ...                           ...           ...
# 1551      20241  3130323                       둔촌역전통시장   12245583047
# 1552      20241  3130324                       길동복조리시장    6115829276
# 1553      20241  3130325                        명일전통시장    4049028444
# 1554      20241  3130326                     고덕 골목형상점가   13509742068
# 1555      20241  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)   11112947641
#
# [1556 rows x 4 columns]

# %%
df_floating_grouped =df_floating[['기준_년분기_코드', '상권_코드', '상권_코드_명', '총_유동인구_수']]
df_floating_grouped = df_floating_grouped[df_floating_grouped['기준_년분기_코드'].isin([20191, 20241])]
df_floating_grouped
# Out:
#        기준_년분기_코드    상권_코드                 상권_코드_명  총_유동인구_수
# 0          20241  3001496             강남 마이스 관광특구    109292
# 1          20241  3001495                 잠실 관광특구   4110178
# 2          20241  3001494              종로?청계 관광특구   8440796
# 3          20241  3001493            동대문패션타운 관광특구   3384560
# 4          20241  3001492  명동 남대문 북창동 다동 무교동 관광특구   6889856
# ...          ...      ...                     ...       ...
# 34638      20191  3110005                     세검정    129171
# 34639      20191  3110004                  대신고등학교    495628
# 34640      20191  3110003                 세검정초등학교    706686
# 34641      20191  3110002                 독립문역 1번    540585
# 34642      20191  3110001                  이북5도청사    155680
#
# [3299 rows x 4 columns]

# %% [markdown]
# 매출액 데이터끼리, 점포수 데이터 끼리 묶기

# %%
df_sales_combined = pd.concat([df_2019_sales_grouped, df_2024_sales_grouped])
print(df_sales_combined.head())
print(df_sales_combined.tail())
# Out:
#    기준_년분기_코드    상권_코드                 상권_코드_명      당월_매출_금액
# 0      20191  3001491                이태원 관광특구   83131949802
# 1      20191  3001492  명동 남대문 북창동 다동 무교동 관광특구  311534240028
# 2      20191  3001493            동대문패션타운 관광특구  108434508028
# 3      20191  3001494              종로·청계 관광특구  247895672197
# 4      20191  3001495                 잠실 관광특구  138146453561
#       기준_년분기_코드    상권_코드                       상권_코드_명     당월_매출_금액
# 1551      20241  3130323                       둔촌역전통시장  12245583047
# 1552      20241  3130324                       길동복조리시장   6115829276
# 1553      20241  3130325                        명일전통시장   4049028444
# 1554      20241  3130326                     고덕 골목형상점가  13509742068
# 1555      20241  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)  11112947641

# %%
df_store_combined = pd.concat([df_2019_store_grouped, df_2024_store_grouped])
print(df_store_combined.head())
print(df_store_combined.tail())
# Out:
#    기준_년분기_코드    상권_코드                 상권_코드_명   점포_수
# 0      20191  3001491                이태원 관광특구   1676
# 1      20191  3001492  명동 남대문 북창동 다동 무교동 관광특구   9063
# 2      20191  3001493            동대문패션타운 관광특구  13496
# 3      20191  3001494              종로·청계 관광특구   5158
# 4      20191  3001495                 잠실 관광특구   2212
#       기준_년분기_코드    상권_코드                       상권_코드_명  점포_수
# 1643      20241  3130323                       둔촌역전통시장   166
# 1644      20241  3130324                       길동복조리시장   117
# 1645      20241  3130325                        명일전통시장    99
# 1646      20241  3130326                     고덕 골목형상점가   155
# 1647      20241  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)  2268

# %% [markdown]
# 하나의 테이블에 합치기

# %%
df_sales_combined['상권_코드'] = df_sales_combined['상권_코드'].astype(str)
df_store_combined['상권_코드'] = df_store_combined['상권_코드'].astype(str)
df_floating_grouped['상권_코드'] = df_floating_grouped['상권_코드'].astype(str)

# %%
combined_data = pd.merge(df_sales_combined, df_store_combined,  on=['기준_년분기_코드','상권_코드',  '상권_코드_명' ], how='inner')
combined_data = pd.merge(combined_data, df_floating_grouped,  on=['기준_년분기_코드','상권_코드',  '상권_코드_명' ], how='inner')
print(combined_data)
# Out:
#       기준_년분기_코드    상권_코드                       상권_코드_명      당월_매출_금액   점포_수  \
# 0         20191  3001491                      이태원 관광특구   83131949802   1676
# 1         20191  3001492        명동 남대문 북창동 다동 무교동 관광특구  311534240028   9063
# 2         20191  3001493                  동대문패션타운 관광특구  108434508028  13496
# 3         20191  3001495                       잠실 관광특구  138146453561   2212
# 4         20191  3001496                   강남 마이스 관광특구  250523338011    842
# ...         ...      ...                           ...           ...    ...
# 3092      20241  3130323                       둔촌역전통시장   12245583047    166
# 3093      20241  3130324                       길동복조리시장    6115829276    117
# 3094      20241  3130325                        명일전통시장    4049028444     99
# 3095      20241  3130326                     고덕 골목형상점가   13509742068    155
# 3096      20241  3130327  평화시장(남평화시장, 제일평화시장, 신평화패션타운)   11112947641   2268
#
#       총_유동인구_수
# 0      2418524
# 1      7851811
# 2      3779788
# 3      3853206
# 4       115445
# ...        ...
# 3092    314557
# 3093    556699
# 3094    335813
# 3095    119598
# 3096     56935
#
# [3097 rows x 6 columns]

# %% [markdown]
# 공간정보 추가하기(shp 파일)

# %%
geometry_only_df = data[['TRDAR_CD', 'geometry', 'RELM_AR']]
gdf_data = gpd.GeoDataFrame(geometry_only_df, geometry='geometry')
gdf_data.rename(columns={'RELM_AR': '상권_면적' }, inplace=True)
sales_merge = gdf_data.merge(combined_data, left_on='TRDAR_CD', right_on='상권_코드')
sales_merge.drop(columns=['TRDAR_CD'], inplace=True)
sales_merge
# Out:
#                                                geometry     상권_면적  기준_년분기_코드  \
# 0     POLYGON ((196955.842 453722.114, 196958.669 45...  149264.0      20191
# 1     POLYGON ((196955.842 453722.114, 196958.669 45...  149264.0      20241
# 2     POLYGON ((201385.38 452513.725, 201385.284 452...  653127.0      20241
# 3     POLYGON ((197550.67 453079.887, 197554.026 453...   49557.0      20191
# 4     POLYGON ((197550.67 453079.887, 197554.026 453...   49557.0      20241
# ...                                                 ...       ...        ...
# 3092  POLYGON ((212814.498 448972.661, 212804.818 44...   29464.0      20241
# 3093  POLYGON ((212922.264 449886.083, 212922.218 44...   27547.0      20191
# 3094  POLYGON ((212922.264 449886.083, 212922.218 44...   27547.0      20241
# 3095  POLYGON ((214945 451011.141, 214946.951 450967...   29082.0      20191
# 3096  POLYGON ((214945 451011.141, 214946.951 450967...   29082.0      20241
#
#         상권_코드            상권_코드_명      당월_매출_금액  점포_수  총_유동인구_수
# 0     3110008    배화여자대학교(박노수미술관)    2193129730   192   1577188
# 1     3110008    배화여자대학교(박노수미술관)    5049589186   261   1263951
# 2     3001494         종로?청계 관광특구  246968942914  4878   8440796
# 3     3130002  세종마을음식문화거리(금천교시장)    9164054725   190    779445
# 4     3130002  세종마을음식문화거리(금천교시장)   14303330271   199    655716
# ...       ...                ...           ...   ...       ...
# 3092  3130324            길동복조리시장    6115829276   117    556699
# 3093  3130325             명일전통시장    2957301531    88    215377
# 3094  3130325             명일전통시장    4049028444    99    335813
# 3095  3130326          고덕 골목형상점가    3238745432    71     23652
# 3096  3130326          고덕 골목형상점가   13509742068   155    119598
#
# [3097 rows x 8 columns]

# %%
sales_merge.isna().sum()
# Out:
# geometry     0
# 상권_면적        0
# 기준_년분기_코드    0
# 상권_코드        0
# 상권_코드_명      0
# 당월_매출_금액     0
# 점포_수         0
# 총_유동인구_수     0
# dtype: int64

# %% [markdown]
# ## 점포수와 매출을 정규화하고 상권지수 만들기

# %% [markdown]
# 각 년도별로 스케일링 하여 지수화 하기

# %%
sales_merge['매출액_면적당'] = (sales_merge['당월_매출_금액'] / sales_merge['상권_면적']).round(2)
sales_merge['점포수_면적당'] = sales_merge['점포_수'] / sales_merge['상권_면적']
sales_merge['유동인구_면적당'] =( sales_merge['총_유동인구_수'] / sales_merge['상권_면적']).round(2)
sales_merge
# Out:
#                                                geometry     상권_면적  기준_년분기_코드  \
# 0     POLYGON ((196955.842 453722.114, 196958.669 45...  149264.0      20191
# 1     POLYGON ((196955.842 453722.114, 196958.669 45...  149264.0      20241
# 2     POLYGON ((201385.38 452513.725, 201385.284 452...  653127.0      20241
# 3     POLYGON ((197550.67 453079.887, 197554.026 453...   49557.0      20191
# 4     POLYGON ((197550.67 453079.887, 197554.026 453...   49557.0      20241
# ...                                                 ...       ...        ...
# 3092  POLYGON ((212814.498 448972.661, 212804.818 44...   29464.0      20241
# 3093  POLYGON ((212922.264 449886.083, 212922.218 44...   27547.0      20191
# 3094  POLYGON ((212922.264 449886.083, 212922.218 44...   27547.0      20241
# 3095  POLYGON ((214945 451011.141, 214946.951 450967...   29082.0      20191
# 3096  POLYGON ((214945 451011.141, 214946.951 450967...   29082.0      20241
#
#         상권_코드            상권_코드_명      당월_매출_금액  점포_수  총_유동인구_수    매출액_면적당  \
# 0     3110008    배화여자대학교(박노수미술관)    2193129730   192   1577188   14692.96
# 1     3110008    배화여자대학교(박노수미술관)    5049589186   261   1263951   33829.92
# 2     3001494         종로?청계 관광특구  246968942914  4878   8440796  378133.11
# 3     3130002  세종마을음식문화거리(금천교시장)    9164054725   190    779445  184919.48
# 4     3130002  세종마을음식문화거리(금천교시장)   14303330271   199    655716  288623.81
# ...       ...                ...           ...   ...       ...        ...
# 3092  3130324            길동복조리시장    6115829276   117    556699  207569.55
# 3093  3130325             명일전통시장    2957301531    88    215377  107354.76
# 3094  3130325             명일전통시장    4049028444    99    335813  146986.19
# 3095  3130326          고덕 골목형상점가    3238745432    71     23652  111365.98
# 3096  3130326          고덕 골목형상점가   13509742068   155    119598  464539.65
#
#        점포수_면적당  유동인구_면적당
# 0     0.001286     10.57
# 1     0.001749      8.47
# 2     0.007469     12.92
# 3     0.003834     15.73
# 4     0.004016     13.23
# ...        ...       ...
# 3092  0.003971     18.89
# 3093  0.003195      7.82
# 3094  0.003594     12.19
# 3095  0.002441      0.81
# 3096  0.005330      4.11
#
# [3097 rows x 11 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_by_period(df, period_code):
    scaler = MinMaxScaler()
    subset = df[df['기준_년분기_코드'] == period_code]
    
    # 스케일링할 열을 선택
    columns_to_scale = ['매출액_면적당', '점포수_면적당', '유동인구_면적당']
    
    # 스케일링
    subset[columns_to_scale] = scaler.fit_transform(subset[columns_to_scale])
    
    # 상권 지수 계산
    subset['상권_지수'] = (
        subset['매출액_면적당'] +
        subset['점포수_면적당'] +
        subset['유동인구_면적당']
        ) / 3
    
    return subset

# 각 기준_년분기_코드에 대해 스케일링 적용
sales_20191 = scale_by_period(sales_merge, 20191)
sales_20241 = scale_by_period(sales_merge, 20241)

# 스케일링된 데이터를 결합
sales_merge_scaled = pd.concat([sales_20191, sales_20241])

print(sales_merge_scaled)
# Out:
#                                                geometry     상권_면적  기준_년분기_코드  \
# 0     POLYGON ((196955.842 453722.114, 196958.669 45...  149264.0      20191
# 3     POLYGON ((197550.67 453079.887, 197554.026 453...   49557.0      20191
# 5     POLYGON ((197428.009 453548.216, 197436.697 45...   38280.0      20191
# 7     MULTIPOLYGON (((201566.474 452608.907, 201567....   31213.0      20191
# 9     POLYGON ((201217.171 452547.873, 201232.462 45...   38586.0      20191
# ...                                                 ...       ...        ...
# 3088  POLYGON ((211759.866 449221.074, 211779.452 44...   20499.0      20241
# 3090  POLYGON ((211924.717 447688.584, 211931.962 44...   36613.0      20241
# 3092  POLYGON ((212814.498 448972.661, 212804.818 44...   29464.0      20241
# 3094  POLYGON ((212922.264 449886.083, 212922.218 44...   27547.0      20241
# 3096  POLYGON ((214945 451011.141, 214946.951 450967...   29082.0      20241
#
#         상권_코드               상권_코드_명     당월_매출_금액  점포_수  총_유동인구_수   매출액_면적당  \
# 0     3110008       배화여자대학교(박노수미술관)   2193129730   192   1577188  0.002495
# 3     3130002     세종마을음식문화거리(금천교시장)   9164054725   190    779445  0.031406
# 5     3130001                  통인시장   6369088775   133    417723  0.028258
# 7     3130020          동묘시장(동묘벼룩시장)   1838944420   157    502932  0.010006
# 9     3130018  동대문문구완구거리(동대문문구완구시장)  49120695263   222    861925  0.216212
# ...       ...                   ...          ...   ...       ...       ...
# 3088  3130322              고분다리전통시장    939198997    90    153107  0.001864
# 3090  3130323               둔촌역전통시장  12245583047   166    314557  0.013614
# 3092  3130324               길동복조리시장   6115829276   117    556699  0.008449
# 3094  3130325                명일전통시장   4049028444    99    335813  0.005983
# 3096  3130326             고덕 골목형상점가  13509742068   155    119598  0.018909
#
#        점포수_면적당  유동인구_면적당     상권_지수
# 0     0.007014  0.105080  0.038196
# 3     0.022334  0.156377  0.070039
# 5     0.020172  0.108460  0.052297
# 7     0.029526  0.160155  0.066562
# 9     0.033876  0.222090  0.157393
# ...        ...       ...       ...
# 3088  0.030784  0.055498  0.029382
# 3090  0.031819  0.063819  0.036417
# 3092  0.027755  0.140342  0.058849
# 3094  0.025033  0.090565  0.040527
# 3096  0.037565  0.030535  0.029003
#
# [3097 rows x 12 columns]
# C:\Users\j2982\Anaconda 3\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\j2982\Anaconda 3\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\j2982\Anaconda 3\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# C:\Users\j2982\Anaconda 3\Lib\site-packages\geopandas\geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#sales_merge[['매출액_norm', '점포수_norm', '유동인구_norm']] = scaler.fit_transform(sales_merge[['매출액_면적당', '점포수_면적당', '유동인구_면적당']])
#sales_merge['1-폐업률'] = 1- sales_merge['폐업률']
#sales_merge['상권_지수'] = (sales_merge['매출액_norm'] + sales_merge['점포수_norm'] + sales_merge['유동인구_norm'] +sales_merge['1-폐업률'] ) / 4
#sales_merge

# %%
# 필터링: 2019_1 분기와 2022_4 분기 데이터만 선택
filtered_df = sales_merge_scaled[sales_merge_scaled['기준_년분기_코드'].isin([20191, 20241])]
# 피벗 테이블 생성
pivot_table = filtered_df.pivot_table(index='상권_코드', 
                                     columns='기준_년분기_코드', 
                                     values='상권_지수',
                                     aggfunc='mean')

# 상권_코드_명 데이터 프레임 생성
code_name_df = filtered_df[['상권_코드', '상권_코드_명', 'geometry']].drop_duplicates().set_index('상권_코드')

# 피벗 테이블에 상권_코드_명 추가
pivot_table = pivot_table.join(code_name_df)
# 상권_코드_명을 첫 번째 열로 이동|
pivot_table = pivot_table.reset_index()
pivot_table = pivot_table[['상권_코드_명', '상권_코드', 20191, 20241, 'geometry']]
pivot_table = pivot_table.dropna(subset=[20191, 20241])
# 결과 출력
pivot_table
# Out:
#                            상권_코드_명    상권_코드     20191     20241  \
# 0                         이태원 관광특구  3001491  0.042915  0.028126
# 1           명동 남대문 북창동 다동 무교동 관광특구  3001492  0.062603  0.042910
# 2                     동대문패션타운 관광특구  3001493  0.075204  0.061134
# 4                          잠실 관광특구  3001495  0.009905  0.008170
# 5                      강남 마이스 관광특구  3001496  0.068098  0.018822
# ...                            ...      ...       ...       ...
# 1566                       둔촌역전통시장  3130323  0.044665  0.036417
# 1567                       길동복조리시장  3130324  0.058359  0.058849
# 1568                        명일전통시장  3130325  0.038154  0.040527
# 1569                     고덕 골목형상점가  3130326  0.013642  0.029003
# 1570  평화시장(남평화시장, 제일평화시장, 신평화패션타운)  3130327  0.193938  0.158463
#
#                                                geometry
# 0     POLYGON ((200205.11 448754.4, 200208.852 44875...
# 1     POLYGON ((198220.924 452166.599, 198221.268 45...
# 2     POLYGON ((201566.793 452246.873, 201567.849 45...
# 4     POLYGON ((210991.687 447357.041, 211069.592 44...
# 5     POLYGON ((205269.67 445368.325, 205255.648 445...
# ...                                                 ...
# 1566  POLYGON ((211924.717 447688.584, 211931.962 44...
# 1567  POLYGON ((212814.498 448972.661, 212804.818 44...
# 1568  POLYGON ((212922.264 449886.083, 212922.218 44...
# 1569  POLYGON ((214945 451011.141, 214946.951 450967...
# 1570  POLYGON ((201000.56 452247.242, 201025.915 452...
#
# [1526 rows x 5 columns]

# %%
#pivot_table_save = pivot_table
#pivot_table_save['상권_코드'] = pivot_table['상권_코드'].astype(str)

# %%
pivot_table['지수_변화'] =  pivot_table[20241] - pivot_table[20191]
pivot_table
# Out:
#                            상권_코드_명    상권_코드     20191     20241  \
# 0                         이태원 관광특구  3001491  0.042915  0.028126
# 1           명동 남대문 북창동 다동 무교동 관광특구  3001492  0.062603  0.042910
# 2                     동대문패션타운 관광특구  3001493  0.075204  0.061134
# 4                          잠실 관광특구  3001495  0.009905  0.008170
# 5                      강남 마이스 관광특구  3001496  0.068098  0.018822
# ...                            ...      ...       ...       ...
# 1566                       둔촌역전통시장  3130323  0.044665  0.036417
# 1567                       길동복조리시장  3130324  0.058359  0.058849
# 1568                        명일전통시장  3130325  0.038154  0.040527
# 1569                     고덕 골목형상점가  3130326  0.013642  0.029003
# 1570  평화시장(남평화시장, 제일평화시장, 신평화패션타운)  3130327  0.193938  0.158463
#
#                                                geometry     지수_변화
# 0     POLYGON ((200205.11 448754.4, 200208.852 44875... -0.014790
# 1     POLYGON ((198220.924 452166.599, 198221.268 45... -0.019693
# 2     POLYGON ((201566.793 452246.873, 201567.849 45... -0.014070
# 4     POLYGON ((210991.687 447357.041, 211069.592 44... -0.001735
# 5     POLYGON ((205269.67 445368.325, 205255.648 445... -0.049276
# ...                                                 ...       ...
# 1566  POLYGON ((211924.717 447688.584, 211931.962 44... -0.008247
# 1567  POLYGON ((212814.498 448972.661, 212804.818 44...  0.000490
# 1568  POLYGON ((212922.264 449886.083, 212922.218 44...  0.002373
# 1569  POLYGON ((214945 451011.141, 214946.951 450967...  0.015361
# 1570  POLYGON ((201000.56 452247.242, 201025.915 452... -0.035475
#
# [1526 rows x 6 columns]

# %%
sorted_pivot_table = pivot_table.sort_values(by='지수_변화', ascending=False)
sorted_pivot_table
# Out:
#                    상권_코드_명    상권_코드     20191     20241  \
# 463                 불광역 7번  3110481  0.059493  0.102340
# 769                 KT대방빌딩  3110797  0.053673  0.081768
# 983                 방이역 2번  3111030  0.047050  0.072124
# 26                   서울대병원  3110023  0.104219  0.128032
# 1389         꿈의숲 장곡 골목형상점가  3130123  0.025384  0.045915
# ...                    ...      ...       ...       ...
# 1303  동대문문구완구거리(동대문문구완구시장)  3130018  0.157393  0.061981
# 1357               청량리종합시장  3130090  0.250291  0.149387
# 1486               독산동 우시장  3130231  0.181322  0.057848
# 1081           용산전자상가(용산역)  3120040  0.229469  0.050519
# 1022                천호초등학교  3111070  0.335533  0.063749
#
#                                                geometry     지수_변화
# 463   POLYGON ((193503.37 457186.048, 193524.677 457...  0.042847
# 769   POLYGON ((191995.786 444069.763, 192007.116 44...  0.028095
# 983   POLYGON ((211645.744 445146.573, 211633.554 44...  0.025074
# 26    POLYGON ((200159.398 453191.625, 200146.703 45...  0.023813
# 1389  POLYGON ((204068.148 457685.025, 204076.776 45...  0.020531
# ...                                                 ...       ...
# 1303  POLYGON ((201217.171 452547.873, 201232.462 45... -0.095411
# 1357  POLYGON ((203629.004 453451.707, 203648.768 45... -0.100903
# 1486  POLYGON ((190950.717 440791.229, 190950.68 440... -0.123474
# 1081  POLYGON ((196758.669 448447.655, 196759.846 44... -0.178950
# 1022  POLYGON ((212117.142 449910.584, 212142.812 44... -0.271784
#
# [1526 rows x 6 columns]

# %%
sorted_pivot_table.head(10)
# Out:
#             상권_코드_명    상권_코드     20191     20241  \
# 463          불광역 7번  3110481  0.059493  0.102340
# 769          KT대방빌딩  3110797  0.053673  0.081768
# 983          방이역 2번  3111030  0.047050  0.072124
# 26            서울대병원  3110023  0.104219  0.128032
# 1389  꿈의숲 장곡 골목형상점가  3130123  0.025384  0.045915
# 308          KT월곡지사  3110318  0.024609  0.044195
# 1343        영동교골목시장  3130074  0.077432  0.096467
# 1176            양평역  3120135  0.050373  0.067254
# 1320     동화동 골목형상점가  3130051  0.059386  0.076016
# 509          아현역 2번  3110532  0.032684  0.048164
#
#                                                geometry     지수_변화
# 463   POLYGON ((193503.37 457186.048, 193524.677 457...  0.042847
# 769   POLYGON ((191995.786 444069.763, 192007.116 44...  0.028095
# 983   POLYGON ((211645.744 445146.573, 211633.554 44...  0.025074
# 26    POLYGON ((200159.398 453191.625, 200146.703 45...  0.023813
# 1389  POLYGON ((204068.148 457685.025, 204076.776 45...  0.020531
# 308   POLYGON ((202964.848 456213.696, 202965.007 45...  0.019585
# 1343  MULTIPOLYGON (((205738.964 448671.652, 205742....  0.019035
# 1176  POLYGON ((190179.853 447402.429, 190251.242 44...  0.016881
# 1320  POLYGON ((201641.835 451506.393, 201684.19 451...  0.016629
# 509   POLYGON ((196364.96 451230.412, 196402.859 451...  0.015480

# %%
sorted_pivot_table.tail(10)
# Out:
#                    상권_코드_명    상권_코드     20191     20241  \
# 103                 금북초등학교  3110106  0.113207  0.026436
# 66                  남정초등학교  3110065  0.136808  0.043489
# 1535         삼성동 시장(삼성동시장)  3130287  0.338786  0.243705
# 1439             아현가구거리상점가  3130181  0.203675  0.108562
# 1354          경동광성상가(경동시장)  3130087  0.160306  0.064969
# 1303  동대문문구완구거리(동대문문구완구시장)  3130018  0.157393  0.061981
# 1357               청량리종합시장  3130090  0.250291  0.149387
# 1486               독산동 우시장  3130231  0.181322  0.057848
# 1081           용산전자상가(용산역)  3120040  0.229469  0.050519
# 1022                천호초등학교  3111070  0.335533  0.063749
#
#                                                geometry     지수_변화
# 103   POLYGON ((202199.783 450865.809, 202200.344 45... -0.086771
# 66    POLYGON ((196970.291 448629.526, 196940.856 44... -0.093320
# 1535  POLYGON ((194098.791 441412.083, 194101.008 44... -0.095081
# 1439  POLYGON ((196417.808 451010.284, 196432.477 45... -0.095113
# 1354  POLYGON ((203459.561 453620.48, 203458.48 4536... -0.095338
# 1303  POLYGON ((201217.171 452547.873, 201232.462 45... -0.095411
# 1357  POLYGON ((203629.004 453451.707, 203648.768 45... -0.100903
# 1486  POLYGON ((190950.717 440791.229, 190950.68 440... -0.123474
# 1081  POLYGON ((196758.669 448447.655, 196759.846 44... -0.178950
# 1022  POLYGON ((212117.142 449910.584, 212142.812 44... -0.271784

# %%
top_10 = sorted_pivot_table.nlargest(10, '지수_변화')
bottom_10 = sorted_pivot_table.nsmallest(10, '지수_변화')

# %%
top_10_names = top_10['상권_코드_명'].tolist()
print("상권 지수 변화 상위 10등 상권:")
for name in top_10_names:
    print(name)

# 하위 10개 상권 이름 출력
bottom_10_names = bottom_10['상권_코드_명'].tolist()
print("\n상권 지수 변화 하위 10등 상권들:")
for name in bottom_10_names:
    print(name)
# Out:
# 상권 지수 변화 상위 10등 상권:
# 불광역 7번
# KT대방빌딩
# 방이역 2번
# 서울대병원
# 꿈의숲 장곡 골목형상점가
# KT월곡지사
# 영동교골목시장
# 양평역
# 동화동 골목형상점가
# 아현역 2번
#
# 상권 지수 변화 하위 10등 상권들:
# 천호초등학교
# 용산전자상가(용산역)
# 독산동 우시장
# 청량리종합시장
# 동대문문구완구거리(동대문문구완구시장)
# 경동광성상가(경동시장)
# 아현가구거리상점가
# 삼성동 시장(삼성동시장)
# 남정초등학교
# 금북초등학교

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# 상위 10개 선 그래프
plt.figure(figsize=(14, 7))

# 상위 10개
plt.subplot(1, 2, 1)
plt.plot(top_10['상권_코드_명'], top_10[20191], marker='o', linestyle='-', color='blue', label='20191')
plt.plot(top_10['상권_코드_명'], top_10[20241], marker='o', linestyle='--', color='red', label='20241')
plt.xlabel('상권 코드명')
plt.ylabel('지수 변화')
plt.title('뜨는 상권 지수 변화 (20191 vs 20241)')
plt.xticks(rotation=45, ha='right')
plt.legend()

# 하위 10개
plt.subplot(1, 2, 2)
plt.plot(bottom_10['상권_코드_명'], bottom_10[20191], marker='o', linestyle='-', color='blue', label='20191')
plt.plot(bottom_10['상권_코드_명'], bottom_10[20241], marker='o', linestyle='--', color='red', label='20241')
plt.xlabel('상권 코드명')
plt.ylabel('지수 변화')
plt.title('죽은 상권 지수 변화 (20191 vs 20241)')
plt.xticks(rotation=45, ha='right')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 죽은상권 & 성장한 상권 10곳 지수 자세히 살펴보기

# %% [markdown]
# 생산자 물가지수
# 1. 2019/1 : 100.07
# 2. 2024/1 : 118.52
#
#
# 약 18% 증가, 매출액볼때 참고

# %%
sales_merge_scaled = sales_merge_scaled.drop(columns=['geometry'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sales_merge_scaled = sales_merge_scaled.drop(columns=['geometry'])
#
# File ~\Anaconda 3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\Anaconda 3\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\Anaconda 3\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\Anaconda 3\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['geometry'] not found in axis"

# %%
for name in bottom_10_names:
    print(sales_merge_scaled[sales_merge_scaled['상권_코드_명'] == name])
# Out:
#         상권_면적  기준_년분기_코드    상권_코드 상권_코드_명   당월_매출_금액  점포_수  총_유동인구_수  \
# 3049  59080.0      20191  3111070  천호초등학교  564145184    56   5943141
# 3050  59080.0      20241  3111070  천호초등학교  731194468    60   1465864
#
#        매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 3049  0.001621  0.004978  1.000000  0.335533
# 3050  0.000503  0.006419  0.184324  0.063749
#         상권_면적  기준_년분기_코드    상권_코드      상권_코드_명       당월_매출_금액  점포_수  총_유동인구_수  \
# 278  365025.0      20191  3120040  용산전자상가(용산역)  1308873572907  3192   1012493
# 279  365025.0      20241  3120040  용산전자상가(용산역)   663928159074  2816   1116252
#
#       매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 278  0.609005  0.051864  0.027538  0.229469
# 279  0.074040  0.054782  0.022734  0.050519
#         상권_면적  기준_년분기_코드    상권_코드  상권_코드_명      당월_매출_금액  점포_수  총_유동인구_수  \
# 2028  63392.0      20191  3130231  독산동 우시장  180411768860   266    230104
# 2029  63392.0      20241  3130231  독산동 우시장  195328756828   270    155946
#
#        매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 2028  0.483366  0.024512  0.036087  0.181322
# 2029  0.125430  0.029836  0.018276  0.057848
#        상권_면적  기준_년분기_코드    상권_코드  상권_코드_명      당월_매출_금액  점포_수  총_유동인구_수  \
# 619  24349.0      20191  3130090  청량리종합시장   72679562905   144    512159
# 620  24349.0      20241  3130090  청량리종합시장  177083963923   146    359691
#
#       매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 619  0.506964  0.034842  0.209067  0.250291
# 620  0.296053  0.042376  0.109733  0.149387
#       상권_면적  기준_년분기_코드    상권_코드               상권_코드_명     당월_매출_금액  점포_수  \
# 9   38586.0      20191  3130018  동대문문구완구거리(동대문문구완구시장)  49120695263   222
# 10  38586.0      20241  3130018  동대문문구완구거리(동대문문구완구시장)  37533508818   197
#
#     총_유동인구_수   매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 9     861925  0.216212  0.033876  0.222090  0.157393
# 10    573399  0.039596  0.035946  0.110401  0.061981
#        상권_면적  기준_년분기_코드    상권_코드       상권_코드_명     당월_매출_금액  점포_수  총_유동인구_수  \
# 625  20976.0      20191  3130087  경동광성상가(경동시장)  43312340716   145    188520
# 626  20976.0      20241  3130087  경동광성상가(경동시장)  55202445216   134    120263
#
#       매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 625  0.350699  0.040848  0.089373  0.160306
# 626  0.107129  0.045207  0.042571  0.064969
#         상권_면적  기준_년분기_코드    상권_코드    상권_코드_명    당월_매출_금액  점포_수  총_유동인구_수  \
# 1396  45816.0      20191  3130181  아현가구거리상점가  4328521799   141   2659890
# 1397  45816.0      20241  3130181  아현가구거리상점가  3421809903   125   1874096
#
#        매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 1396  0.016045  0.017785  0.577195  0.203675
# 1397  0.003040  0.018784  0.303863  0.108562
#         상권_면적  기준_년분기_코드    상권_코드        상권_코드_명    당월_매출_금액  점포_수  총_유동인구_수  \
# 2390  13340.0      20191  3130287  삼성동 시장(삼성동시장)  1013016170    60   1311255
# 2391  13340.0      20241  3130287  삼성동 시장(삼성동시장)  1892925146    68   1237985
#
#        매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 2390  0.012897  0.026326  0.977135  0.338786
# 2391  0.005776  0.035888  0.689450  0.243705
#        상권_면적  기준_년분기_코드    상권_코드 상권_코드_명     당월_매출_금액  점포_수  총_유동인구_수  \
# 340  18065.0      20191  3110065  남정초등학교  38300628011    59     57063
# 341  18065.0      20241  3110065  남정초등학교  37779000000    62     52190
#
#       매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 340  0.360092  0.018918  0.031415  0.136808
# 341  0.085130  0.023865  0.021471  0.043489
#        상권_면적  기준_년분기_코드    상권_코드 상권_코드_명   당월_매출_금액  점포_수  총_유동인구_수   매출액_면적당  \
# 428  21366.0      20191  3110106  금북초등학교  253239588    34    706595  0.002012
# 429  21366.0      20241  3110106  금북초등학교  486967295    37    191984  0.000927
#
#       점포수_면적당  유동인구_면적당     상권_지수
# 428  0.008848   0.32876  0.113207
# 429  0.011589   0.06679  0.026436

# %% [markdown]
# 천호초등학교: 매출액 약간 증가, 유동인구수 크게 감소-> 죽은 상권 제외
#
# 용산전자상가(용산) 역: 매출액 크게 감
# )
# 독산동시장 우: 유동인구수 크게 , 매출액 감소 -> 제외
# 시청량리종합시장 : 매출액 증가, 유동인구수 크게 감소 -> 죽은 상권 제외
#
# 동대문문구완구거리(동대문문구완구시장: 3지표 모두 골고루 감소 )
#
# 경동광성상가(경동시: 매출액 약간 증가, 점포+유동인구 감소 -> 죽은 상권 제외
#
# )
# 아현가구거리: 3지표 모두 감소상
# 점가
# 삼성동 시장(삼성: 유동인구수만 약간 감소 -> 죽은 상권 제외동
# 시장)
# 남: 유동인구수만 약간 감소 -> 죽은 상권 제외 정
# 초등학교
# : 매출 크게 증가, 유동인구수 크게 감소 -> 죽은 상권 제외금북초등학교)
# 남정초등학교

# %% [markdown]
# **죽은 상권 : 용산전자상가(용산역), 동대문문구완구거리(동대문문구완구시장),아현가구거리상점가**

# %%
for name in top_10_names:
    print(sales_merge_scaled[sales_merge_scaled['상권_코드_명'] == name])
# Out:
#         상권_면적  기준_년분기_코드    상권_코드 상권_코드_명    당월_매출_금액  점포_수  총_유동인구_수  \
# 1392  88375.0      20191  3110481  불광역 7번  2333248600   252   1400807
# 1393  88375.0      20241  3110481  불광역 7번  3932496065   245   3403737
#
#        매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 1392  0.004483  0.016426  0.157570  0.059493
# 1393  0.001811  0.019102  0.286107  0.102340
#        상권_면적  기준_년분기_코드    상권_코드 상권_코드_명   당월_매출_금액  점포_수  총_유동인구_수   매출액_면적당  \
# 2223  8947.0      20191  3110797  KT대방빌딩  433442605    41    113336  0.008227
# 2224  8947.0      20241  3110797  KT대방빌딩  675552755    38    255883  0.003073
#
#        점포수_면적당  유동인구_면적당     상권_지수
# 2223  0.026835  0.125957  0.053673
# 2224  0.029750  0.212481  0.081768
#         상권_면적  기준_년분기_코드    상권_코드 상권_코드_명    당월_매출_금액  점포_수  총_유동인구_수  \
# 2963  50911.0      20191  3111030  방이역 2번  2048151009   156    597228
# 2964  50911.0      20241  3111030  방이역 2번  4847099423   170   1297146
#
#        매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 2963  0.006832  0.017705  0.116612  0.047050
# 2964  0.003875  0.023194  0.189302  0.072124
#       상권_면적  기준_년분기_코드    상권_코드 상권_코드_명    당월_매출_금액  점포_수  총_유동인구_수   매출액_면적당  \
# 86  15969.0      20191  3110023   서울대병원   651488155    35    471115  0.006928
# 87  15969.0      20241  3110023   서울대병원  1114713420    35    787424  0.002841
#
#      점포수_면적당  유동인구_면적당     상권_지수
# 86  0.012458  0.293270  0.104219
# 87  0.014911  0.366345  0.128032
#        상권_면적  기준_년분기_코드    상권_코드        상권_코드_명    당월_매출_금액  점포_수  총_유동인구_수  \
# 865  12762.0      20191  3130123  꿈의숲 장곡 골목형상점가   251012297    32     74977
# 866  12762.0      20241  3130123  꿈의숲 장곡 골목형상점가  1273622930    45    187512
#
#       매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 865  0.003340  0.014357  0.058455  0.025384
# 866  0.004062  0.024544  0.109138  0.045915
#        상권_면적  기준_년분기_코드    상권_코드 상권_코드_명   당월_매출_금액  점포_수  총_유동인구_수   매출액_면적당  \
# 984  76869.0      20191  3110318  KT월곡지사  415934883    72    525704  0.000918
# 985  76869.0      20241  3110318  KT월곡지사  879596820    78   1300794  0.000465
#
#       점포수_면적당  유동인구_면적당     상권_지수
# 984  0.004911  0.067999  0.024609
# 985  0.006413  0.125706  0.044195
#        상권_면적  기준_년분기_코드    상권_코드  상권_코드_명   당월_매출_금액  점포_수  총_유동인구_수  \
# 475  14261.0      20191  3130074  영동교골목시장  914085681    39    295018
# 476  14261.0      20241  3130074  영동교골목시장  833485846    29    524462
#
#       매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 475  0.010886  0.015724  0.205686  0.077432
# 476  0.002378  0.013768  0.273254  0.096467
#         상권_면적  기준_년분기_코드    상권_코드 상권_코드_명    당월_매출_금액  점포_수  총_유동인구_수  \
# 2166  36584.0      20191  3120135     양평역  2600007228   280    345098
# 2167  36584.0      20241  3120135     양평역  2061357204   494    506857
#
#        매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 2166  0.012070  0.045303  0.093747  0.050373
# 2167  0.002293  0.096572  0.102897  0.067254
#        상권_면적  기준_년분기_코드    상권_코드     상권_코드_명     당월_매출_금액  점포_수  총_유동인구_수  \
# 161  60206.0      20191  3130051  동화동 골목형상점가   1350154583   225    923942
# 162  60206.0      20241  3130051  동화동 골목형상점가  10200251079   241   1565342
#
#       매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 161  0.003808  0.021752  0.152600  0.059386
# 162  0.006896  0.027986  0.193165  0.076016
#         상권_면적  기준_년분기_코드    상권_코드 상권_코드_명    당월_매출_금액  점포_수  총_유동인구_수  \
# 1433  61152.0      20191  3110532  아현역 2번  4254652683   120    462334
# 1434  61152.0      20241  3110532  아현역 2번  5074071271   120   1052206
#
#        매출액_면적당   점포수_면적당  유동인구_면적당     상권_지수
# 1433  0.011816  0.011079  0.075157  0.032684
# 1434  0.003377  0.013254  0.127860  0.048164

# %% [markdown]
# 성장한 상권은 (영동교골목시장, 양평역, 아현역 2번)을 제외하고 뚜렷한 성장세를 보임

# %% [markdown]
# 용산전자상가(용산역), 동대문문구완구거리(동대문문구완구시장),아현가구거리상점가: 모두 비슷한 업종이 모인 상점거리 유형

# %% [markdown]
# # 2. 상권 활성화 원인 찾기

# %% [markdown]
# ## 변수들 설명

# %% [markdown]
# 1. 성별: 상주인구의 성비 / 서울시 상권분석서비스(상주인구-상권)
# 2. 거주인구: 상권의 거주인구 수 / 서울시 상권분석서비스(상주인구-상권)
# 3. 직장인구: 상권의 직장인구 수 / 서울시 상권분석서비스(직장인구-상권)
# 4. 상권 면적: 해당 상권의 총 면적 / 서울시 상권분석서비스(영역-상권)
# 5. 유동인구: 해당 상권의 평균 유동인구 / 서울시 상권분석서비스(길단위인구-상권)
# 6. 소득수준: 해당 상주인구의 평균 소득 / 서울시 상권분석서비스(소득소비-상권)
# 7. 지출수준: 상주인구의 평균 지출 총금액 / 서울시 상권분석서비스(소득소비-상권)
# 8. 지하철역: 해당 상권내 지하철 역의 개수 / 서울시 상권분석서비스(집객시설-상권)
# 9. 버스 정류장: 해당 상권 내에 위치한 버스 정류장의 개수 / 서울시 상권분석서비스(집객시설-상권)

# %% [markdown]
# ## 2. 파일 로드하기

# %%
import pandas as pd
import geopandas as gpd
import numpy as np

path_income = 'data/서울시 상권분석서비스(소득소비-상권).csv'
path_facility = 'data/서울시 상권분석서비스(집객시설-상권).csv'
path_floating = 'data/서울시 상권분석서비스(길단위인구-상권).csv'
path_population = 'data/서울시 상권분석서비스(상주인구-상권).csv'
path_office = 'data/서울시 상권분석서비스(직장인구-상권).csv'
path_area = 'data/서울시 상권분석서비스(영역-상권)/서울시 상권분석서비스(영역-상권).shp'

df_income = pd.read_csv(path_income, encoding='euc-kr')
df_facility = pd.read_csv(path_facility, encoding='euc-kr')
df_floating = pd.read_csv(path_floating, encoding='euc-kr')
df_population = pd.read_csv(path_population, encoding='euc-kr')
df_office = pd.read_csv(path_office, encoding='euc-kr')
df_area = gpd.read_file(path_area)

print(df_income.head())
print(df_facility.head())
print(df_floating.head())
print(df_population.head())
print(df_office.head())
print(df_area.head())
# Out:
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드   상권_코드_명  월_평균_소득_금액  소득_구간_코드  \
# 0      20231        A       골목상권  3110005       세검정   3768541.0       8.0
# 1      20231        A       골목상권  3110006   부암동주민센터   3963935.0       8.0
# 2      20231        A       골목상권  3110025     충신시장옆   2770370.0       6.0
# 3      20231        A       골목상권  3110648  양천향교역 7번   3402010.0       7.0
# 4      20231        A       골목상권  3110026  종로5가역 4번   2729503.0       6.0
#
#         지출_총금액   식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액   의료비_지출_총금액  \
# 0  884701599.0  221446948.0   109882417.0   64738346.0  111988892.0
# 1  267177363.0   71242932.0    32618743.0   19192280.0   36992515.0
# 2  232818153.0   65006144.0    27756184.0   17256496.0   32610254.0
# 3          NaN          NaN           NaN          NaN          NaN
# 4   76260454.0   21823990.0     9075986.0    6042567.0   10672979.0
#
#      교통_지출_총금액   여가_지출_총금액   문화_지출_총금액    교육_지출_총금액   유흥_지출_총금액
# 0  149822911.0  37478670.0  25606895.0  126544371.0  37192149.0
# 1   42702682.0  11024632.0   7714004.0   34834591.0  10854984.0
# 2   37600382.0   8314184.0   7107301.0   27335346.0   9831862.0
# 3          NaN         NaN         NaN          NaN         NaN
# 4   11514334.0   2981752.0   2362812.0    8598637.0   3187397.0
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드          상권_코드_명  집객시설_수  관공서_수  \
# 0      20234        A       골목상권  3110008  배화여자대학교(박노수미술관)       9    NaN
# 1      20241        A       골목상권  3110008  배화여자대학교(박노수미술관)       9    NaN
# 2      20234        A       골목상권  3110009            자하문터널       3    NaN
# 3      20241        A       골목상권  3110009            자하문터널       3    NaN
# 4      20233        A       골목상권  3110008  배화여자대학교(박노수미술관)       9    NaN
#
#    은행_수  종합병원_수  일반_병원_수  ...  대학교_수  백화점_수  슈퍼마켓_수  극장_수  숙박_시설_수  공항_수  \
# 0   NaN     NaN      NaN  ...    NaN    NaN     NaN   NaN      NaN   NaN
# 1   NaN     NaN      NaN  ...    NaN    NaN     NaN   NaN      NaN   NaN
# 2   NaN     NaN      NaN  ...    NaN    NaN     NaN   NaN      NaN   NaN
# 3   NaN     NaN      NaN  ...    NaN    NaN     NaN   NaN      NaN   NaN
# 4   NaN     NaN      NaN  ...    NaN    NaN     NaN   NaN      NaN   NaN
#
#    철도_역_수  버스_터미널_수  지하철_역_수  버스_정거장_수
# 0     NaN       NaN      NaN       4.0
# 1     NaN       NaN      NaN       4.0
# 2     NaN       NaN      NaN       3.0
# 3     NaN       NaN      NaN       3.0
# 4     NaN       NaN      NaN       4.0
#
# [5 rows x 25 columns]
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  총_유동인구_수  \
# 0      20241        U       관광특구  3001496             강남 마이스 관광특구    109292
# 1      20241        U       관광특구  3001495                 잠실 관광특구   4110178
# 2      20241        U       관광특구  3001494              종로?청계 관광특구   8440796
# 3      20241        U       관광특구  3001493            동대문패션타운 관광특구   3384560
# 4      20241        U       관광특구  3001492  명동 남대문 북창동 다동 무교동 관광특구   6889856
#
#    남성_유동인구_수  여성_유동인구_수  연령대_10_유동인구_수  연령대_20_유동인구_수  ...  시간대_14_17_유동인구_수  \
# 0      54238      55054           7982          21853  ...             27041
# 1    1976808    2133370         434196         915211  ...            653233
# 2    4496772    3944023         358062        1523184  ...           1808704
# 3    1595828    1788732         188119         645950  ...            524693
# 4    3343470    3546388         335824        1194547  ...           1706632
#
#    시간대_17_21_유동인구_수  시간대_21_24_유동인구_수  월요일_유동인구_수  화요일_유동인구_수  수요일_유동인구_수  \
# 0             22995              6011       15002       16018       17973
# 1            879474            477929      570999      570194      589977
# 2           1691285            660774     1258576     1328555     1410371
# 3            620807            401942      504854      524755      553766
# 4           1327800            343472     1040403     1133875     1202348
#
#    목요일_유동인구_수  금요일_유동인구_수  토요일_유동인구_수  일요일_유동인구_수
# 0       17774       17305       13328       11892
# 1      580551      598178      621983      578294
# 2     1345939     1334099      998247      765010
# 3      540100      497858      381895      381333
# 4     1130314     1103850      706014      573054
#
# [5 rows x 27 columns]
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드             상권_코드_명  총_상주인구_수  \
# 0      20194        D       발달상권  3120021              시청역_8번        26
# 1      20194        D       발달상권  3120022         북창동(시청역_6번)       261
# 2      20194        D       발달상권  3120023                서울시청        19
# 3      20194        D       발달상권  3120024                 회현역      1740
# 4      20194        D       발달상권  3120025  롯데백화점(시청광장 지하쇼핑센터)         1
#
#    남성_상주인구_수  여성_상주인구_수  연령대_10_상주인구_수  연령대_20_상주인구_수  ...  \
# 0         16         10              0              2  ...
# 1        167         94              2             21  ...
# 2         10          9              2              0  ...
# 3        902        838            100            136  ...
# 4          1          0              0              0  ...
#
#    남성연령대_60_이상_상주인구_수  여성연령대_10_상주인구_수  여성연령대_20_상주인구_수  여성연령대_30_상주인구_수  \
# 0                  10                0                0                2
# 1                  70                2               10                9
# 2                   6                2                0                0
# 3                 424               56               72               74
# 4                   1                0                0                0
#
#    여성연령대_40_상주인구_수  여성연령대_50_상주인구_수  여성연령대_60_이상_상주인구_수  총_가구_수  아파트_가구_수  \
# 0                0                2                   6      15         0
# 1                7               23                  43     237         0
# 2                1                3                   3      14         0
# 3               91              127                 418    1172         0
# 4                0                0                   0       1         0
#
#    비_아파트_가구_수
# 0          15
# 1         237
# 2          14
# 3        1172
# 4           1
#
# [5 rows x 29 columns]
#    기준_년분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드               상권_코드_명  총_직장_인구_수  \
# 0      20191        A       골목상권  3110013              체부동홍종문가옥         87
# 1      20191        D       발달상권  3120062                  신설동역      11307
# 2      20191        A       골목상권  3110023                 서울대병원        131
# 3      20191        R       전통시장  3130011                  충신시장        342
# 4      20191        R       전통시장  3130018  동대문문구완구거리(동대문문구완구시장)        271
#
#    남성_직장_인구_수  여성_직장_인구_수  연령대_10_직장_인구_수  연령대_20_직장_인구_수  ...  \
# 0          57          30               0              11  ...
# 1        4711        6596              32            1358  ...
# 2          46          85               3              34  ...
# 3         201         141               4              76  ...
# 4         166         105               0              20  ...
#
#    남성연령대_30_직장_인구_수  남성연령대_40_직장_인구_수  남성연령대_50_직장_인구_수  남성연령대_60_이상_직장_인구_수  \
# 0                18                14                13                   10
# 1              1343              1338               898                  681
# 2                 6                 9                10                   12
# 3                72                47                30                   10
# 4                40                45                40                   31
#
#    여성연령대_10_직장_인구_수  여성연령대_20_직장_인구_수  여성연령대_30_직장_인구_수  여성연령대_40_직장_인구_수  \
# 0                 0                 9                 7                 6
# 1                20               919              1300              2039
# 2                 1                27                10                18
# 3                 1                37                35                40
# 4                 0                10                15                29
#
#    여성연령대_50_직장_인구_수  여성연령대_60_이상_직장_인구_수
# 0                 6                    2
# 1              1677                  641
# 2                23                    6
# 3                24                    4
# 4                26                   25
#
# [5 rows x 26 columns]
#   TRDAR_SE_C TRDAR_SE_1 TRDAR_CD         TRDAR_CD_N  XCNTS_VALU  YDNTS_VALU  \
# 0          A       골목상권  3110008    배화여자대학교(박노수미술관)    197093.0    453418.0
# 1          U       관광특구  3001494         종로·청계 관광특구    199796.0    452274.0
# 2          R       전통시장  3130021             신설종합시장    201854.0    452569.0
# 3          R       전통시장  3130002  세종마을음식문화거리(금천교시장)    197423.0    453030.0
# 4          R       전통시장  3130001               통인시장    197351.0    453449.0
#
#   SIGNGU_CD SIGNGU_CD_ ADSTRD_CD   ADSTRD_CD_   RELM_AR  \
# 0     11110        종로구  11110515        청운효자동  149264.0
# 1     11110        종로구  11110615  종로1·2·3·4가동  653127.0
# 2     11110        종로구  11110710         숭인2동    9800.0
# 3     11110        종로구  11110530          사직동   49557.0
# 4     11110        종로구  11110515        청운효자동   38280.0
#
#                                             geometry
# 0  POLYGON ((196955.842 453722.114, 196958.669 45...
# 1  POLYGON ((201385.38 452513.725, 201385.284 452...
# 2  POLYGON ((201937.121 452552.083, 201872.576 45...
# 3  POLYGON ((197550.67 453079.887, 197554.026 453...
# 4  POLYGON ((197428.009 453548.216, 197436.697 45...

# %% [markdown]
# ## 3. 하나의 데이터프레임으로 만들기(상권별로)

# %%
required_columns = [
    ["기준_년분기_코드", "상권_코드", "상권_코드_명", "월_평균_소득_금액", "지출_총금액"],  # df1에서 필요한 열
    ["기준_년분기_코드", "상권_코드", "상권_코드_명","지하철_역_수", "버스_정거장_수"],         # df2에서 필요한 열
    ["기준_년분기_코드", "상권_코드", "상권_코드_명", "총_유동인구_수"],         # df3에서 필요한 열
    ["기준_년분기_코드", "상권_코드", "상권_코드_명", "총_상주인구_수", "남성_상주인구_수", "여성_상주인구_수"] ,      # df4에서 필요한 열
     ["기준_년분기_코드", "상권_코드", "상권_코드_명", "총_직장_인구_수"]     # df5에서 필요한 열
   
]
# 필요한 열만 선택
df1_selected = df_income[required_columns[0]]
df2_selected = df_facility[required_columns[1]]
df3_selected = df_floating[required_columns[2]]
df4_selected = df_population[required_columns[3]]
df5_selected = df_office[required_columns[4]]


merged_df = df1_selected
for df in [df2_selected, df3_selected, df4_selected, df5_selected]:
    merged_df = pd.merge(merged_df, df, on=["기준_년분기_코드", "상권_코드", "상권_코드_명"], how="inner")

merged_df
# Out:
#        기준_년분기_코드    상권_코드                 상권_코드_명  월_평균_소득_금액        지출_총금액  \
# 0          20231  3110005                     세검정   3768541.0  8.847016e+08
# 1          20231  3110006                 부암동주민센터   3963935.0  2.671774e+08
# 2          20231  3110025                   충신시장옆   2770370.0  2.328182e+08
# 3          20231  3110648                양천향교역 7번   3402010.0           NaN
# 4          20231  3110026                종로5가역 4번   2729503.0  7.626045e+07
# ...          ...      ...                     ...         ...           ...
# 21620      20232  3001492  명동 남대문 북창동 다동 무교동 관광특구   3071908.0  7.990605e+08
# 21621      20232  3001493            동대문패션타운 관광특구   3624671.0  1.889505e+09
# 21622      20232  3001494              종로?청계 관광특구   2268084.0  1.880810e+09
# 21623      20232  3001495                 잠실 관광특구   4220819.0  8.751577e+09
# 21624      20232  3001496             강남 마이스 관광특구   7010917.0           NaN
#
#        지하철_역_수  버스_정거장_수  총_유동인구_수  총_상주인구_수  남성_상주인구_수  여성_상주인구_수  총_직장_인구_수
# 0          NaN       6.0    114445      2153       1046       1107       1057
# 1          NaN       1.0      8336       671        329        342         27
# 2          NaN       NaN    290561       523        280        243        213
# 3          NaN       6.0    154832      1356        587        769         13
# 4          NaN       NaN    328618       130         61         69        190
# ...        ...       ...       ...       ...        ...        ...        ...
# 21620      3.0      44.0   7258225       600        365        235     104830
# 21621      5.0      17.0   3408217      1807        941        866       5916
# 21622      3.0      28.0   8580607      1720       1092        628      32892
# 21623      3.0      20.0   4116726      5902       2885       3017      25240
# 21624      NaN       8.0    111108        19         11          8      15904
#
# [21625 rows x 12 columns]

# %%
df_area = df_area.rename(columns={
    'TRDAR_CD' : '상권_코드',
    'TRDAR_CD_N': '상권_코드_명'
})
df_area
# Out:
#      TRDAR_SE_C TRDAR_SE_1    상권_코드            상권_코드_명  XCNTS_VALU  \
# 0             A       골목상권  3110008    배화여자대학교(박노수미술관)    197093.0
# 1             U       관광특구  3001494         종로·청계 관광특구    199796.0
# 2             R       전통시장  3130021             신설종합시장    201854.0
# 3             R       전통시장  3130002  세종마을음식문화거리(금천교시장)    197423.0
# 4             R       전통시장  3130001               통인시장    197351.0
# ...         ...        ...      ...                ...         ...
# 1645          R       전통시장  3130322           고분다리전통시장    211771.0
# 1646          R       전통시장  3130323            둔촌역전통시장    211868.0
# 1647          R       전통시장  3130324            길동복조리시장    212690.0
# 1648          R       전통시장  3130325             명일전통시장    212839.0
# 1649          R       전통시장  3130326          고덕 골목형상점가    215010.0
#
#       YDNTS_VALU SIGNGU_CD SIGNGU_CD_ ADSTRD_CD   ADSTRD_CD_   RELM_AR  \
# 0       453418.0     11110        종로구  11110515        청운효자동  149264.0
# 1       452274.0     11110        종로구  11110615  종로1·2·3·4가동  653127.0
# 2       452569.0     11110        종로구  11110710         숭인2동    9800.0
# 3       453030.0     11110        종로구  11110530          사직동   49557.0
# 4       453449.0     11110        종로구  11110515        청운효자동   38280.0
# ...          ...       ...        ...       ...          ...       ...
# 1645    449208.0     11740        강동구  11740620         천호3동   20499.0
# 1646    447599.0     11740        강동구  11740660         성내3동   36613.0
# 1647    448844.0     11740        강동구  11740685           길동   29464.0
# 1648    449976.0     11740        강동구  11740530         명일1동   27547.0
# 1649    450928.0     11740        강동구  11740560         고덕2동   29082.0
#
#                                                geometry
# 0     POLYGON ((196955.842 453722.114, 196958.669 45...
# 1     POLYGON ((201385.38 452513.725, 201385.284 452...
# 2     POLYGON ((201937.121 452552.083, 201872.576 45...
# 3     POLYGON ((197550.67 453079.887, 197554.026 453...
# 4     POLYGON ((197428.009 453548.216, 197436.697 45...
# ...                                                 ...
# 1645  POLYGON ((211759.866 449221.074, 211779.452 44...
# 1646  POLYGON ((211924.717 447688.584, 211931.962 44...
# 1647  POLYGON ((212814.498 448972.661, 212804.818 44...
# 1648  POLYGON ((212922.264 449886.083, 212922.218 44...
# 1649  POLYGON ((214945 451011.141, 214946.951 450967...
#
# [1650 rows x 12 columns]

# %% [markdown]
# ## 4. 변수들 조정

# %%
#merged_df['상권_코드'] = merged_df['상권_코드'].astype(str)
#merged_df
df_area['상권_코드'] = df_area['상권_코드'].astype(int)

# %%
merged_df = pd.merge(merged_df, df_area[['상권_코드', 'RELM_AR']], on='상권_코드', how='inner')
merged_df=merged_df.rename(columns={
   'RELM_AR': '상권_영역_크기'
})
merged_df
# Out:
#        기준_년분기_코드    상권_코드       상권_코드_명  월_평균_소득_금액       지출_총금액  지하철_역_수  \
# 0          20231  3110005           세검정   3768541.0  884701599.0      NaN
# 1          20232  3110005           세검정   3768541.0  884701599.0      NaN
# 2          20233  3110005           세검정   3768541.0  884701599.0      NaN
# 3          20234  3110005           세검정   3768541.0  884701599.0      NaN
# 4          20241  3110005           세검정   3768541.0          NaN      NaN
# ...          ...      ...           ...         ...          ...      ...
# 21620      20213  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
# 21621      20214  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
# 21622      20221  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
# 21623      20222  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
# 21624      20223  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
#
#        버스_정거장_수  총_유동인구_수  총_상주인구_수  남성_상주인구_수  여성_상주인구_수  총_직장_인구_수  상권_영역_크기
# 0           6.0    114445      2153       1046       1107       1057  244923.0
# 1           6.0    111693      2153       1046       1107       1057  244923.0
# 2           6.0    110053      2153       1046       1107       1057  244923.0
# 3           6.0    128743      2153       1046       1107       1057  244923.0
# 4           6.0    125332      2153       1046       1107       1057  244923.0
# ...         ...       ...       ...        ...        ...        ...       ...
# 21620       1.0     65395        13         10          3         17    2721.0
# 21621       1.0     73907        13         10          3         17    2721.0
# 21622       1.0     71127        13         10          3         17    2721.0
# 21623       1.0     75414        13         10          3         17    2721.0
# 21624       1.0     73872        13         10          3         17    2721.0
#
# [21625 rows x 13 columns]

# %%
merged_df.loc[:, '상주인구_성비'] = (
    merged_df['남성_상주인구_수'] / 
    merged_df['여성_상주인구_수'] * 100
)
merged_df = merged_df.drop(columns=['남성_상주인구_수', '여성_상주인구_수'])
merged_df.replace([np.inf, -np.inf], np.nan, inplace=True)
merged_df.dropna(subset=['상주인구_성비'], inplace=True)
merged_df
# Out:
#        기준_년분기_코드    상권_코드       상권_코드_명  월_평균_소득_금액       지출_총금액  지하철_역_수  \
# 0          20231  3110005           세검정   3768541.0  884701599.0      NaN
# 1          20232  3110005           세검정   3768541.0  884701599.0      NaN
# 2          20233  3110005           세검정   3768541.0  884701599.0      NaN
# 3          20234  3110005           세검정   3768541.0  884701599.0      NaN
# 4          20241  3110005           세검정   3768541.0          NaN      NaN
# ...          ...      ...           ...         ...          ...      ...
# 21620      20213  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
# 21621      20214  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
# 21622      20221  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
# 21623      20222  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
# 21624      20223  3130284  관악종합시장(신원시장)   2656625.0          NaN      NaN
#
#        버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  상권_영역_크기     상주인구_성비
# 0           6.0    114445      2153       1057  244923.0   94.489612
# 1           6.0    111693      2153       1057  244923.0   94.489612
# 2           6.0    110053      2153       1057  244923.0   94.489612
# 3           6.0    128743      2153       1057  244923.0   94.489612
# 4           6.0    125332      2153       1057  244923.0   94.489612
# ...         ...       ...       ...        ...       ...         ...
# 21620       1.0     65395        13         17    2721.0  333.333333
# 21621       1.0     73907        13         17    2721.0  333.333333
# 21622       1.0     71127        13         17    2721.0  333.333333
# 21623       1.0     75414        13         17    2721.0  333.333333
# 21624       1.0     73872        13         17    2721.0  333.333333
#
# [21581 rows x 12 columns]

# %%
merged_df['지출_총금액'] = merged_df['지출_총금액'].apply(lambda x: '{:.2f}'.format(x) if pd.notnull(x) else x)
merged_df
# Out:
#        기준_년분기_코드    상권_코드       상권_코드_명  월_평균_소득_금액        지출_총금액  지하철_역_수  \
# 0          20231  3110005           세검정   3768541.0  884701599.00      NaN
# 1          20232  3110005           세검정   3768541.0  884701599.00      NaN
# 2          20233  3110005           세검정   3768541.0  884701599.00      NaN
# 3          20234  3110005           세검정   3768541.0  884701599.00      NaN
# 4          20241  3110005           세검정   3768541.0           NaN      NaN
# ...          ...      ...           ...         ...           ...      ...
# 21620      20213  3130284  관악종합시장(신원시장)   2656625.0           NaN      NaN
# 21621      20214  3130284  관악종합시장(신원시장)   2656625.0           NaN      NaN
# 21622      20221  3130284  관악종합시장(신원시장)   2656625.0           NaN      NaN
# 21623      20222  3130284  관악종합시장(신원시장)   2656625.0           NaN      NaN
# 21624      20223  3130284  관악종합시장(신원시장)   2656625.0           NaN      NaN
#
#        버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  상권_영역_크기     상주인구_성비
# 0           6.0    114445      2153       1057  244923.0   94.489612
# 1           6.0    111693      2153       1057  244923.0   94.489612
# 2           6.0    110053      2153       1057  244923.0   94.489612
# 3           6.0    128743      2153       1057  244923.0   94.489612
# 4           6.0    125332      2153       1057  244923.0   94.489612
# ...         ...       ...       ...        ...       ...         ...
# 21620       1.0     65395        13         17    2721.0  333.333333
# 21621       1.0     73907        13         17    2721.0  333.333333
# 21622       1.0     71127        13         17    2721.0  333.333333
# 21623       1.0     75414        13         17    2721.0  333.333333
# 21624       1.0     73872        13         17    2721.0  333.333333
#
# [21581 rows x 12 columns]

# %%
merged_df_filtered = merged_df[merged_df["기준_년분기_코드"] == 20224]
merged_df_filtered
# Out:
#        기준_년분기_코드    상권_코드   상권_코드_명  월_평균_소득_금액        지출_총금액  지하철_역_수  \
# 13         20224  3110005       세검정   3768541.0  884701599.00      NaN
# 27         20224  3110006   부암동주민센터   3963935.0  267177363.00      NaN
# 41         20224  3110025     충신시장옆   2770370.0  232818153.00      NaN
# 55         20224  3110648  양천향교역 7번   3402010.0           NaN      NaN
# 69         20224  3110026  종로5가역 4번   2729503.0   76260454.00      NaN
# ...          ...      ...       ...         ...           ...      ...
# 21545      20224  3110122    마장역 2번   2648703.0  569859649.00      NaN
# 21558      20224  3110948    헌인가구단지   2255617.0   33867500.00      NaN
# 21571      20224  3130153    창동역상점가   2356062.0           NaN      NaN
# 21585      20224  3130240   영등포유통상가   1745098.0           NaN      NaN
# 21598      20224  3110764    문래역 3번   3002882.0           NaN      NaN
#
#        버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  상권_영역_크기     상주인구_성비
# 13          6.0    112754      2153       1057  244923.0   94.489612
# 27          1.0      8585       671         27   91486.0   96.198830
# 41          NaN    266935       523        213   39184.0  115.226337
# 55          6.0    182424      1356         13  283983.0   76.332900
# 69          NaN    313090       130        190   16485.0   88.405797
# ...         ...       ...       ...        ...       ...         ...
# 21545       7.0    293387       706        461   80335.0  103.458213
# 21558       3.0        43       159         57  198674.0  114.864865
# 21571       5.0    166175       162        229   33628.0  440.000000
# 21585       NaN     29799        19       1400   47667.0  850.000000
# 21598       3.0     60785        56        541   18152.0  143.478261
#
# [1540 rows x 12 columns]

# %% [markdown]
# ## 5.NAN값 처리
# 지하쳘, 버스는 nan -> 0

# %%
merged_df_filtered.loc[:, '지하철_역_수'] = merged_df_filtered['지하철_역_수'].fillna(0)
merged_df_filtered.loc[:, '버스_정거장_수'] = merged_df_filtered['버스_정거장_수'].fillna(0)
merged_df_filtered
# Out:
#        기준_년분기_코드    상권_코드   상권_코드_명  월_평균_소득_금액        지출_총금액  지하철_역_수  \
# 13         20224  3110005       세검정   3768541.0  884701599.00      0.0
# 27         20224  3110006   부암동주민센터   3963935.0  267177363.00      0.0
# 41         20224  3110025     충신시장옆   2770370.0  232818153.00      0.0
# 55         20224  3110648  양천향교역 7번   3402010.0           NaN      0.0
# 69         20224  3110026  종로5가역 4번   2729503.0   76260454.00      0.0
# ...          ...      ...       ...         ...           ...      ...
# 21545      20224  3110122    마장역 2번   2648703.0  569859649.00      0.0
# 21558      20224  3110948    헌인가구단지   2255617.0   33867500.00      0.0
# 21571      20224  3130153    창동역상점가   2356062.0           NaN      0.0
# 21585      20224  3130240   영등포유통상가   1745098.0           NaN      0.0
# 21598      20224  3110764    문래역 3번   3002882.0           NaN      0.0
#
#        버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  상권_영역_크기     상주인구_성비
# 13          6.0    112754      2153       1057  244923.0   94.489612
# 27          1.0      8585       671         27   91486.0   96.198830
# 41          0.0    266935       523        213   39184.0  115.226337
# 55          6.0    182424      1356         13  283983.0   76.332900
# 69          0.0    313090       130        190   16485.0   88.405797
# ...         ...       ...       ...        ...       ...         ...
# 21545       7.0    293387       706        461   80335.0  103.458213
# 21558       3.0        43       159         57  198674.0  114.864865
# 21571       5.0    166175       162        229   33628.0  440.000000
# 21585       0.0     29799        19       1400   47667.0  850.000000
# 21598       3.0     60785        56        541   18152.0  143.478261
#
# [1540 rows x 12 columns]

# %%
merged_df_filtered = merged_df_filtered.dropna()
merged_df_filtered
merged_df_filtered.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ## 6. 각변수 지수화하기(MINN MAX)

# %%
import numpy as np

numeric_df = merged_df_filtered.select_dtypes(include=[np.number])

# 무한대 값 확인
print(np.isinf(numeric_df).any())
merged_df_filtered.isna().sum().sum()
# Out:
# 기준_년분기_코드     False
# 상권_코드         False
# 월_평균_소득_금액    False
# 지하철_역_수       False
# 버스_정거장_수      False
# 총_유동인구_수      False
# 총_상주인구_수      False
# 총_직장_인구_수     False
# 상권_영역_크기      False
# 상주인구_성비       False
# dtype: bool
# 0

# %%
columns_to_scale = [
    '월_평균_소득_금액', '지출_총금액', '지하철_역_수', '버스_정거장_수',
    '총_유동인구_수', '총_상주인구_수', '총_직장_인구_수', '상권_영역_크기', '상주인구_성비'
]

# NaN 및 Inf 값을 포함하는 행 제거
merged_df_filtered = merged_df_filtered.dropna(subset=columns_to_scale)
merged_df_filtered = merged_df_filtered[~merged_df_filtered.isin([np.inf, -np.inf]).any(axis=1)]

# 정규화할 데이터 추출
data_to_scale = merged_df_filtered[columns_to_scale]

# 정규화 수행
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_to_scale)

# 정규화된 데이터프레임 생성
scaled_df = pd.DataFrame(scaled_data, columns=columns_to_scale, index=merged_df_filtered.index)

# 원본 데이터프레임에 정규화된 데이터 병합
merged_df_filtered[columns_to_scale] = scaled_df

# 결과 확인
merged_df_filtered
# Out:
#        기준_년분기_코드    상권_코드       상권_코드_명  월_평균_소득_금액    지출_총금액  지하철_역_수  \
# 13         20224  3110005           세검정    0.337006  0.074470      0.0
# 27         20224  3110006       부암동주민센터    0.360454  0.022399      0.0
# 41         20224  3110025         충신시장옆    0.217222  0.019501      0.0
# 69         20224  3110026      종로5가역 4번    0.212318  0.006300      0.0
# 83         20224  3110949          한남IC    0.364830  0.028343      0.0
# ...          ...      ...           ...         ...       ...      ...
# 21489      20224  3001493  동대문패션타운 관광특구    0.319741  0.159196      1.0
# 21503      20224  3001494    종로?청계 관광특구    0.156946  0.158463      0.6
# 21517      20224  3001495       잠실 관광특구    0.391281  0.737819      0.6
# 21545      20224  3110122        마장역 2번    0.202622  0.047921      0.0
# 21558      20224  3110948        헌인가구단지    0.155450  0.002726      0.0
#
#        버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  상권_영역_크기   상주인구_성비
# 13     0.070588  0.013018  0.100759   0.010074  0.098696  0.071539
# 27     0.011765  0.000987  0.031306   0.000248  0.036340  0.073394
# 41     0.000000  0.030827  0.024370   0.002022  0.015085  0.094044
# 69     0.000000  0.036158  0.005952   0.001803  0.005860  0.064937
# 83     0.000000  0.044051  0.028587   0.016045  0.024408  0.060848
# ...         ...       ...       ...        ...       ...       ...
# 21489  0.200000  0.394885  0.084544   0.056425  0.245459  0.086918
# 21503  0.329412  1.000000  0.080467   0.313759  0.264587  0.157705
# 21517  0.235294  0.482790  0.276455   0.240764  1.000000  0.072771
# 21545  0.082353  0.033882  0.032946   0.004388  0.031808  0.081272
# 21558  0.035294  0.000000  0.007311   0.000534  0.079901  0.093652
#
# [1514 rows x 12 columns]

# %%
pivot_table['상권_코드'] = pivot_table['상권_코드'].astype(int)

# %%
final_df = pd.merge(merged_df_filtered, pivot_table[['상권_코드',  20224]], on='상권_코드', how='inner')
final_df
# Out:
#       기준_년분기_코드    상권_코드       상권_코드_명  월_평균_소득_금액    지출_총금액  지하철_역_수  \
# 0         20224  3110005           세검정    0.337006  0.074470      0.0
# 1         20224  3110006       부암동주민센터    0.360454  0.022399      0.0
# 2         20224  3110025         충신시장옆    0.217222  0.019501      0.0
# 3         20224  3110949          한남IC    0.364830  0.028343      0.0
# 4         20224  3110012         성곡미술관    0.538589  0.103142      0.0
# ...         ...      ...           ...         ...       ...      ...
# 1431      20224  3001493  동대문패션타운 관광특구    0.319741  0.159196      1.0
# 1432      20224  3001494    종로?청계 관광특구    0.156946  0.158463      0.6
# 1433      20224  3001495       잠실 관광특구    0.391281  0.737819      0.6
# 1434      20224  3110122        마장역 2번    0.202622  0.047921      0.0
# 1435      20224  3110948        헌인가구단지    0.155450  0.002726      0.0
#
#       버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  상권_영역_크기   상주인구_성비     20224
# 0     0.070588  0.013018  0.100759   0.010074  0.098696  0.071539  0.003063
# 1     0.011765  0.000987  0.031306   0.000248  0.036340  0.073394  0.000616
# 2     0.000000  0.030827  0.024370   0.002022  0.015085  0.094044  0.002327
# 3     0.000000  0.044051  0.028587   0.016045  0.024408  0.060848  0.005975
# 4     0.000000  0.071264  0.089652   0.009930  0.049695  0.060791  0.023276
# ...        ...       ...       ...        ...       ...       ...       ...
# 1431  0.200000  0.394885  0.084544   0.056425  0.245459  0.086918  0.503967
# 1432  0.329412  1.000000  0.080467   0.313759  0.264587  0.157705  0.298357
# 1433  0.235294  0.482790  0.276455   0.240764  1.000000  0.072771  0.238749
# 1434  0.082353  0.033882  0.032946   0.004388  0.031808  0.081272  0.010189
# 1435  0.035294  0.000000  0.007311   0.000534  0.079901  0.093652  0.001641
#
# [1436 rows x 13 columns]

# %%
final_df = final_df.rename(columns={
    20224 : '상권_활성화_지수'
})
final_df
# Out:
#       기준_년분기_코드    상권_코드       상권_코드_명  월_평균_소득_금액    지출_총금액  지하철_역_수  \
# 0         20224  3110005           세검정    0.337006  0.074470      0.0
# 1         20224  3110006       부암동주민센터    0.360454  0.022399      0.0
# 2         20224  3110025         충신시장옆    0.217222  0.019501      0.0
# 3         20224  3110949          한남IC    0.364830  0.028343      0.0
# 4         20224  3110012         성곡미술관    0.538589  0.103142      0.0
# ...         ...      ...           ...         ...       ...      ...
# 1431      20224  3001493  동대문패션타운 관광특구    0.319741  0.159196      1.0
# 1432      20224  3001494    종로?청계 관광특구    0.156946  0.158463      0.6
# 1433      20224  3001495       잠실 관광특구    0.391281  0.737819      0.6
# 1434      20224  3110122        마장역 2번    0.202622  0.047921      0.0
# 1435      20224  3110948        헌인가구단지    0.155450  0.002726      0.0
#
#       버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  상권_영역_크기   상주인구_성비  상권_활성화_지수
# 0     0.070588  0.013018  0.100759   0.010074  0.098696  0.071539   0.003063
# 1     0.011765  0.000987  0.031306   0.000248  0.036340  0.073394   0.000616
# 2     0.000000  0.030827  0.024370   0.002022  0.015085  0.094044   0.002327
# 3     0.000000  0.044051  0.028587   0.016045  0.024408  0.060848   0.005975
# 4     0.000000  0.071264  0.089652   0.009930  0.049695  0.060791   0.023276
# ...        ...       ...       ...        ...       ...       ...        ...
# 1431  0.200000  0.394885  0.084544   0.056425  0.245459  0.086918   0.503967
# 1432  0.329412  1.000000  0.080467   0.313759  0.264587  0.157705   0.298357
# 1433  0.235294  0.482790  0.276455   0.240764  1.000000  0.072771   0.238749
# 1434  0.082353  0.033882  0.032946   0.004388  0.031808  0.081272   0.010189
# 1435  0.035294  0.000000  0.007311   0.000534  0.079901  0.093652   0.001641
#
# [1436 rows x 13 columns]

# %% [markdown]
# ## 7. 상권 활성화 지수와의 상관관계분석

# %%
columns_to_analyze = [
    '월_평균_소득_금액', '지출_총금액', '지하철_역_수', '버스_정거장_수',
    '총_유동인구_수', '총_상주인구_수', '총_직장_인구_수', '상권_영역_크기', '상주인구_성비', '상권_활성화_지수'
]
df_analysis = final_df[columns_to_analyze]

# %%
correlation_matrix = df_analysis.corr()
correlation_with_activation = correlation_matrix['상권_활성화_지수'].sort_values(ascending=False)

# 결과 출력
print(correlation_with_activation)
# Out:
# 상권_활성화_지수     1.000000
# 상권_영역_크기      0.691157
# 총_직장_인구_수     0.665658
# 버스_정거장_수      0.631062
# 지하철_역_수       0.539349
# 총_유동인구_수      0.487859
# 월_평균_소득_금액    0.202824
# 지출_총금액        0.194188
# 총_상주인구_수      0.071105
# 상주인구_성비       0.054279
# Name: 상권_활성화_지수, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"  # 윈도우의 경우 맑은 고딕 경로
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)


plt.figure(figsize=(16, 8))

for i, column in enumerate(correlation_with_activation.index):
    plt.subplot(2, 5, i + 1)
    sns.scatterplot(x=df_analysis[column], y=df_analysis['상권_활성화_지수'])
    plt.title(f'{column} (corr: {correlation_with_activation[column]:.2f})')
    plt.xlabel(column)
    plt.ylabel('상권_활성화_지수')

plt.tight_layout()
plt.show()

# %% [markdown]
# **상권 활성화의 주요 원인: 직장 인구수, 교통 편리성(버스+지하철)**

# %%
#교통 편리성: 버스와 지하철을 모두 고려한 변수
df_analysis.loc[:, '교통_편리성'] = (df_analysis['지하철_역_수'] + df_analysis['버스_정거장_수']) / 2
df_analysis
# Out:
# C:\Users\j2982\AppData\Local\Temp\ipykernel_25592\2854329195.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_analysis.loc[:, '교통_편리성'] = (df_analysis['지하철_역_수'] + df_analysis['버스_정거장_수']) / 2
#       월_평균_소득_금액    지출_총금액  지하철_역_수  버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  \
# 0       0.337006  0.074470      0.0  0.070588  0.013018  0.100759   0.010074
# 1       0.360454  0.022399      0.0  0.011765  0.000987  0.031306   0.000248
# 2       0.217222  0.019501      0.0  0.000000  0.030827  0.024370   0.002022
# 3       0.364830  0.028343      0.0  0.000000  0.044051  0.028587   0.016045
# 4       0.538589  0.103142      0.0  0.000000  0.071264  0.089652   0.009930
# ...          ...       ...      ...       ...       ...       ...        ...
# 1431    0.319741  0.159196      1.0  0.200000  0.394885  0.084544   0.056425
# 1432    0.156946  0.158463      0.6  0.329412  1.000000  0.080467   0.313759
# 1433    0.391281  0.737819      0.6  0.235294  0.482790  0.276455   0.240764
# 1434    0.202622  0.047921      0.0  0.082353  0.033882  0.032946   0.004388
# 1435    0.155450  0.002726      0.0  0.035294  0.000000  0.007311   0.000534
#
#       상권_영역_크기   상주인구_성비  상권_활성화_지수    교통_편리성
# 0     0.098696  0.071539   0.003063  0.035294
# 1     0.036340  0.073394   0.000616  0.005882
# 2     0.015085  0.094044   0.002327  0.000000
# 3     0.024408  0.060848   0.005975  0.000000
# 4     0.049695  0.060791   0.023276  0.000000
# ...        ...       ...        ...       ...
# 1431  0.245459  0.086918   0.503967  0.600000
# 1432  0.264587  0.157705   0.298357  0.464706
# 1433  1.000000  0.072771   0.238749  0.417647
# 1434  0.031808  0.081272   0.010189  0.041176
# 1435  0.079901  0.093652   0.001641  0.017647
#
# [1436 rows x 11 columns]

# %%
#교통 편리성: 버스와 지하철을 모두 고려한 변수
final_df.loc[:, '교통_편리성'] = (final_df['지하철_역_수'] + final_df['버스_정거장_수']) / 2
final_df
# Out:
#       기준_년분기_코드    상권_코드       상권_코드_명  월_평균_소득_금액    지출_총금액  지하철_역_수  \
# 0         20224  3110005           세검정    0.337006  0.074470      0.0
# 1         20224  3110006       부암동주민센터    0.360454  0.022399      0.0
# 2         20224  3110025         충신시장옆    0.217222  0.019501      0.0
# 3         20224  3110949          한남IC    0.364830  0.028343      0.0
# 4         20224  3110012         성곡미술관    0.538589  0.103142      0.0
# ...         ...      ...           ...         ...       ...      ...
# 1431      20224  3001493  동대문패션타운 관광특구    0.319741  0.159196      1.0
# 1432      20224  3001494    종로?청계 관광특구    0.156946  0.158463      0.6
# 1433      20224  3001495       잠실 관광특구    0.391281  0.737819      0.6
# 1434      20224  3110122        마장역 2번    0.202622  0.047921      0.0
# 1435      20224  3110948        헌인가구단지    0.155450  0.002726      0.0
#
#       버스_정거장_수  총_유동인구_수  총_상주인구_수  총_직장_인구_수  상권_영역_크기   상주인구_성비  상권_활성화_지수  \
# 0     0.070588  0.013018  0.100759   0.010074  0.098696  0.071539   0.003063
# 1     0.011765  0.000987  0.031306   0.000248  0.036340  0.073394   0.000616
# 2     0.000000  0.030827  0.024370   0.002022  0.015085  0.094044   0.002327
# 3     0.000000  0.044051  0.028587   0.016045  0.024408  0.060848   0.005975
# 4     0.000000  0.071264  0.089652   0.009930  0.049695  0.060791   0.023276
# ...        ...       ...       ...        ...       ...       ...        ...
# 1431  0.200000  0.394885  0.084544   0.056425  0.245459  0.086918   0.503967
# 1432  0.329412  1.000000  0.080467   0.313759  0.264587  0.157705   0.298357
# 1433  0.235294  0.482790  0.276455   0.240764  1.000000  0.072771   0.238749
# 1434  0.082353  0.033882  0.032946   0.004388  0.031808  0.081272   0.010189
# 1435  0.035294  0.000000  0.007311   0.000534  0.079901  0.093652   0.001641
#
#         교통_편리성
# 0     0.035294
# 1     0.005882
# 2     0.000000
# 3     0.000000
# 4     0.000000
# ...        ...
# 1431  0.600000
# 1432  0.464706
# 1433  0.417647
# 1434  0.041176
# 1435  0.017647
#
# [1436 rows x 14 columns]

# %%
pip install mplcursors
# Out:
# Collecting mplcursors
#   Downloading mplcursors-0.5.3.tar.gz (88 kB)
#      ---------------------------------------- 0.0/88.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/88.8 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/88.8 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/88.8 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/88.8 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/88.8 kB ? eta -:--:--
#      -------- ------------------------------ 20.5/88.8 kB 65.2 kB/s eta 0:00:02
#      -------- ------------------------------ 20.5/88.8 kB 65.2 kB/s eta 0:00:02
#      ------------- ------------------------- 30.7/88.8 kB 72.6 kB/s eta 0:00:01
#      ------------- ------------------------- 30.7/88.8 kB 72.6 kB/s eta 0:00:01
#      ----------------- --------------------- 41.0/88.8 kB 81.9 kB/s eta 0:00:01
#      -------------------------- ----------- 61.4/88.8 kB 121.3 kB/s eta 0:00:01
#      -------------------------------------- 88.8/88.8 kB 167.5 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib!=3.7.1,>=3.1 in c:\users\j2982\anaconda 3\lib\site-packages (from mplcursors) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\j2982\anaconda 3\lib\site-packages (from matplotlib!=3.7.1,>=3.1->mplcursors) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\j2982\anaconda 3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.7.1,>=3.1->mplcursors) (1.16.0)
# Building wheels for collected packages: mplcursors
#   Building wheel for mplcursors (pyproject.toml): started
#   Building wheel for mplcursors (pyproject.toml): finished with status 'done'
#   Created wheel for mplcursors: filename=mplcursors-0.5.3-py3-none-any.whl size=20745 sha256=6d84a230b03432e363b8cf59f8fe9a44eec6b9c7365fb786c32839d206cff8c8
#   Stored in directory: c:\users\j2982\appdata\local\pip\cache\wheels\10\b6\58\05d5160d055ea77855fc4324d32a33f9ddea3e5289f315e738
# Successfully built mplcursors
# Installing collected packages: mplcursors
# Successfully installed mplcursors-0.5.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 해당 산접도는 태블로로 다시 그림(상세정보 확인 가능)

# %%
import mplcursors

# 산점도 그리기
plt.figure(figsize=(20, 12))  # 플롯 크기를 키움

# 산점도
scatter = plt.scatter(
    final_df['교통_편리성'],
    final_df['총_직장_인구_수'],
    s=final_df['상권_활성화_지수'] * 500,  # 상권 활성화 지수를 원의 크기로, 스케일 조정
    alpha=0.5,
    c=final_df['상권_활성화_지수'],  # 상권 활성화 지수를 색상으로
    cmap='viridis'
)

# 색상 바
plt.colorbar(scatter, label='상권_활성화_지수')

plt.xlabel('교통편리성 (지하철_역_수 + 버스_정거장_수) / 2')
plt.ylabel('총_직장_인구_수')
plt.title('교통편리성과 직장 인구에 따른 상권 활성화 지수 산점도')
plt.grid(True)

# mplcursors for interactive annotations
cursor = mplcursors.cursor(scatter, hover=True)

@cursor.connect("add")
def on_add(sel):
    index = sel.index
    sel.annotation.set(text=(
        f"상권_코드: {df_analysis.iloc[index]['상권_코드']}\n"
        f"상권_코드_명: {df_analysis.iloc[index]['상권_코드_명']}\n"
        f"교통_편리성: {df_analysis.iloc[index]['교통_편리성']}\n"
        f"총_직장_인구_수: {df_analysis.iloc[index]['총_직장_인구_수']}\n"
        f"상권_활성화_지수: {df_analysis.iloc[index]['상권_활성화_지수']}"
    ))

plt.show()
